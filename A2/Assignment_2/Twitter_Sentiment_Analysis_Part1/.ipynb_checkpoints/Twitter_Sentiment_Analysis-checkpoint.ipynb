# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sn
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 1: Load the data
# For this you can use python built in file reader to load the data, you will have to split each row to create list of Tweets(X) and list of sentiment Labels(Y). An alternate option is to use [Pandas](https://pandas.pydata.org/pandas-docs/stable/index.html) to load the csv file, then return the two cols in pandas dataframe as arrays.

# %%
def load_data(filename):
    """
    Load data from file

    Args:
        filename : Name of the file from which the data is to be loaded
    
    Returns: tweet_X, sentiment_Y
    tweet_X: list of tweets
    sentiment_Y: list of sentiment lables correponding to each tweet
    """
    df = pd.read_csv(filename)
    df.head()
    y = df[['class']]
    x = df[['text']]
    return x,y#update these
tweet_X_task1, sentiment_label_Y_task1=load_data("twitter-sanders-apple2.csv")
tweet_X_task2, sentiment_label_Y_task2=load_data("twitter-sanders-apple3.csv")

# %% [markdown]
# ### Step 2: Preprocessing
# Before we move on to the actual classification section, there is some data cleaning up to be done. As a matter of fact, this step is critical, as it ultimately effects the learning process of your model. So basically [this](https://ibb.co/G9zcx2K) can happen to your model.
#
# We will keep to simple preprocessing to make out task easier. Some of you might disagree with the preprocessing steps stated below, hence we wish to mention that choosing different preprocessing steps depend on the nature of task at hand and alos that there are always trade offs associated augmenting the orignal dataset.<br>
#
# You are required to perform the following preprocessing steps:<br>
# <i>(note that you must figure out the order of steps for ease of preprocessing yourself)</i><br>
# <ul>
#     <li><b>Remove all punctuations.</b><br> Although this makes things simple it is not always a good idea to remove punctuation for example in sentiment classification the use of exclaimation marks, can be used to intensify the sentiment of a given word or sentence hence might be useful, nevertheless it increases the vocabulary size hence we will not use it here. e.g. <blockquote>The opening ceremony was extreamly disappointing!!! #PSL5</blockquote>
#         Removing pucntutations also removes emojis which might also be helpful.
#     </li><br>
#     <li><b>Remove all html tags.</b><br> Mostly done for all tasks </li><br>
#     <li><b>Replace all @sometext with AT_TOKEN.</b><br>Since there will be lots of different usernames or words that can follow @ we will choose to ignore them as they dont have much sentiment information. Might be usefull for Named Entity Recognition </li>e.g.
#     <blockquote>@apple will be converted to AT_TOKEN</blockquote>
#     <li><b>Remove all # symbols.</b> We want to remove the # in #applesucks so that it is not treated differently that any other word in the sentence, this migh also help us to reduce our vocabulary size.</li><br>
#     <li><b>Convert the tweets to lower case text</b><br> Although all CAPS convey meaningful information for sentiment analysis we mostly convert text to lower case to reduce vocabulary size by reducing the number of variations. For example Car, cAr ,CAR, caR and car will now be treated as a single token car.</li><br>
#     <li><b>Tokenize the text</b><br></li><br>
# </ul>

# %%
sentiment_label_Y_task1
# Out:
#     class
# 0     Pos
# 1     Pos
# 2     Pos
# 3     Pos
# 4     Pos
# ..    ...
# 474   Neg
# 475   Neg
# 476   Neg
# 477   Neg
# 478   Neg
#
# [479 rows x 1 columns]

# %%
for val in tweet_X_task1['text']:
    print(val)
# Out:
# Now all @Apple has to do is get swype on the iphone and it will be crack. Iphone that is
# @Apple will be adding more carrier support to the iPhone 4S (just announced)
# Hilarious @youtube video - guy does a duet with @apple 's Siri. Pretty much sums up the love affair! http://t.co/8ExbnQjY
# @RIM you made it too easy for me to switch to @Apple iPhone. See ya!
# I just realized that the reason I got into twitter was ios5 thanks @apple
# I'm a current @Blackberry user little bit disappointed with it! Should I move to @Android or @Apple @iphone
# The 16 strangest things Siri has said so far. I am SOOO glad that @Apple gave Siri a sense of humor! http://t.co/TWAeUDBp via @HappyPlace
# Great up close & personal event @Apple tonight in Regent St store!
# From which companies do you experience the best customer service aside from @zappos and @apple?
# Just apply for a job at @Apple hope they call me lol
# RT @JamaicanIdler: Lmao I think @apple is onto something magical! I am DYING!!! haha. Siri suggested where to find whores and where to h ...
# Lmao I think @apple is onto something magical! I am DYING!!! haha. Siri suggested where to find whores and where to hide a body lolol
# RT @PhillipRowntree: Just registered as an @apple developer... Here's hoping I can actually do it... Any help greatly appreciated!
# Wow. Great deals on refurbed #iPad (first gen) models. RT: Apple offers great deals on refurbished 1st-gen iPads http://t.co/ukWOKBGd @Apple
# Just registered as an @apple developer... Here's hoping I can actually do it... Any help greatly appreciated!
#  ! Currently learning Mandarin for my upcoming trip to Hong Kong. I gotta hand it to @Apple iPhones & their uber useful flashcard apps
# Come to the dark side @gretcheneclark: Hey @apple if you send me a free iPhone I will publicly and ceremoniously burn my #BlackBerry.
# Hey @apple if you send me a free iPhone (any version will do) I will publicly and ceremoniously burn my #BlackBerry.
# Thank you @apple for Find My Mac - just located and wiped my stolen Air. #smallvictory #thievingbastards
# Thanks to @Apple Covent Garden #GeniusBar for replacing my MacBook keyboard/cracked wristpad during my lunch break today out of warranty.
# @DailyDealChat @apple Thanks!!
# iPads Replace Bound Playbooks on Some N.F.L. Teams http://t.co/2UXAWKwf @apple @nytimes
# @apple..good ipad
# @apple @siri is efffing amazing!!
# Amazing new @Apple iOs 5 feature.  http://t.co/jatFVfpM
# RT @TripLingo: We're one of a few Featured Education Apps on the @Apple **Website** today sweet! http://t.co/0yWvbe1Z
# We're one of a few Featured Education Apps on the @Apple **Website** today sweet! http://t.co/0yWvbe1Z
# When you want something done right you do it yourself... or go to @Apple. AT&T you're useless these days. #yourdaysarenumbered
# We did an unexpected workshop for the #iPhone4S at @apple yesterday and we got an awesome amount of info #notjustaboutthephone @gamerchik16
# &lt;3 #ios5 @apple
# --- RT @Apple No question bro. RT @AintEeenTrippin: Should I get dis iPhone or a EVO 3D?
# RT @imightbewrong: I'm OVER people bitching about the #iPhone4S... I think it's the smartest phone I've ever had and I'm very happy.   : ...
# I'm OVER people bitching about the #iPhone4S... I think it's the smartest phone I've ever had and I'm very happy.   :)  Way to go @Apple!
# @Twitter CEO points to @Apple as 'corporate mentor' as @iOS signups triple http://t.co/GCY8iphN
# At the bus with my iPhone ;) thxx @apple
# @azee1v1 @apple @umber AppStore is well done so is iTunes on the mobile devices.  I was talking about desktop app.
# NYTimes: Coach Wants to See You. And Bring Your iPad. http://t.co/J2FTiEnG #iPad @apple set red 42 red 42 hut hut @NFL wish I had an #iPad
# @apple @jilive @DanielPink: Apple sells 4 million iPhone 4S units in first weekend ... Steve Jobs brilliance lives on for ever! #iphone #RVA
# @bkad5161 than apologize to @apple ;)
# @Apple downloads of iOS 5 are proving popular with users  -- http://t.co/NSHLfiUX
# Lmfao look at the argument I had with Siri !!@ijustine @apple http://t.co/D4VjL7SI
# Incredible: 4 million iPhone 4Ss in 3 days. 135% better than the iPhone 4 http://t.co/1FMJxTMM @apple #iphone4s
# Save me from #HP's unwanted OS! Help me buy an #iPhone! I have seen the light! #lol http://t.co/8gUP9Acz #backchannel @apple
# Well @apple fixed my #ios5 battery drain problem with a replacement iPhone 4 -- it's working like a champ now
# Currently ordering a BRAND NEW MACBOOK PRO!!! Bahhh... my MacBook is 5 years old. I'll miss it. But it's time. cc: @Apple -
# you are so blessed. @apple
# #Siri now knows who my dad mom brother and girlfriend is.  Thanks @apple
# Well at least the @apple store has amazing call waiting music! #need4s
# #sweet... #apple replaced my glass #probono. thank you @apple
# Not Bad! @Apple Sells Over 4 Million #IPhones in Debut Weekend - Bloomberg http://t.co/AVSl3ygU - #smartphone #sm RT @VinodRad
# loving new technology from @apple iPhone 4s mac air and iCloud are unreal #technology
# I'm loving this new IOS5 update :) @apple
# Another mention for Apple Store: http://t.co/fiIOApKt - RT @floridamike Once again getting great customer service from the @apple store ...
# Time to go get my iPhone 4s.  Looking forward to sticking it to the man by no longer paying for most texts.  Thanks @apple.
# hey @apple I hate my computer i need a #mack wanna send me a free one.
# Thank you @apple. My new gf(iphone4s) is great!  She does everything!
# #iCloud set up was flawless and works like a champ! To the Cloud @Apple
# @Wisconsin_Mommy @Apple I'd totally email the company... I always get great service at our @Apple store!
# @apple loving the new IOS5 upgrade for the iPhone!
# The nice @apple tech support guy fixed my iTouch =D
# Once again getting great customer service from the @apple store at millenia mall.
# Is it just me or is #iOS5 faster for the iPad? @apple
# I love our @apple imac even though I haven't seen my hubby in 3 days now! #geek
# making the switch from @Android to @Apple #iphone #iphone4S #smartphone #stevejobs (@ Apple Store) http://t.co/kj6pJvkH
# So THANKFUL for the incredible people @apple for going above and beyond and offering to and replacing my  water-damaged Macbook Pro!!! Wow!
# Play on ma man. Loving the camera in the #iphone4s. Well done @apple  #fb http://t.co/tmdFqRe1
# So yeah... @apple #iOS5 #readinglists have changed my life. #nowicanspendevenmoretimeonmyphone.
# @Apple Safari Reader owns the worldwide web
# I love @apple service . My case has cracked 3x and I go in and they hand me a case and I walk out
# #10twitterpeopleiwouldliketomeet @coollike @TheGadgetShow  @thelittleappkid @Jon4Lakers @BenRubery @Apple @twitter @FXhomeHitFilm  (-2)
# Said to have laid out the next 4 years @apple.Jobs last iPhone is 2012 not the iPhone4S. iPhone(4G/5) 2012 is magical! http://t.co/DxxklUBp
# Kind of excited. On my way to my last class right now and then going to the @Apple store so buy #MacOSC Snow Leopard and Lion :-)
# i used to be with @blackberry over 4-5yrs .. after all the disruptions and lost gigs thx to their service im moving to @apple #iphone
# Apple sells 4 million iPhones in 3 days @apple keep doing what you are doing because you are doing it well! http://t.co/ZZc6bE0w
# Yessss! I'm lovin the iPhone update especially the slide down bar at top of screen =) good job @Apple.
# 4 millions in a weekend 16 #iPhone4S per second. This is madness?! no this is @Apple !!!
# .@apple you got me. I'm now invested. MacBook Pro next year. Time to get on selling more of my #android gear
# @iancollinsuk @apple I like what you did there...!
# I just sent my grandma a post card using my #CardsApp thanks @Apple
# Sorry @BlackBerry I'm moving to @Apple.
# @KostaTsetsekas @apple Putting it in the wash is kind of the equivalent to Will it blend? Glad to hear it's still alive.
# Laundering Ari's iPhone not my finest moment. But after drying in bag of (organic :-) rice for 4 days it booted up!!!!!!!!!!! @apple
# Bravo @Apple! http://t.co/BgoTzj7K
# God Bless @YouTube @apple for  #appletv & our bad ass system. LOVING #PrincessOfChina. GB to @coldplay & @rihanna too :)
# Been off twitter for a few days as I smashed my iPhone but @apple were very nice and gave me a new one :)
# Thank you @Apple iOS 5 for email pop up on the lock screen and opening it when unlocking.
# One word - #wow. RT @jldavid iPhone 4S First Weekend Sales Top Four Million: http://t.co/Zx5Pw0GT (via @apple)
# This good here iPhone will do me VERY well today. Thanks to the gods that are @apple.
# RT @MN2NOVA: Love ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! #ios5 @apple
# Love ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! #ios5 @apple
# Love #ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! @apple #lovemyiphone
# Updated my iOS and started using cloud services. Pretty bad ass @apple my #iPhone 3GS still the champ.
# Gone for a run beautiful morning  man do I love iOS 5 @apple #iPhone
# @apple your simply the best.
# I must admit @apple has made me a very happy camper! I have text tones now! Lol! Ring tone: #MakeMeProud Drakes vers! Text tone: Nicki's
# Day305 I'm thankful for the great customer service received today from @Apple via phone CS new phone on the way #365daysofgratefulness
# S/O to @apple for replacing my phone for free
# Loving the new iPod update @apple
# @alexlindsay My wife upgraded her iPhone 4. I think Siri alone is worth the upgrade. Looking forward to @Apple continuing to enhance Siri.
# RT @tomkeene Thx @instagram Thx @apple #hypo #D-76 #tri-x http://t.co/BPPJwncp
# @SteveJobs being honored tonite @Apple...A truly great loss to the world.He will so be missed
# Thx @instagram Thx @apple #hypo #D-76 #tri-x http://t.co/D7EeJHBT
# Loving my new #iPhone4S thanks @apple for #ios5
# i love this. so much. thank you @apple.  http://t.co/Ui8lOEzX
# @apple the iPhone 4s is great #genius
# @apple Cards app notifies me the card I sent has arrived at local post office and should be delivered today... Sunday. Truly is #magic.
# Love my new I0S5 @Apple updates. Just when I think it can't get any better somehow it simplifies my life more. That's right-it's an Apple.
# @apple Siri is amazing
# @rygurl you need an @apple iphone4S with Siri!
# Meet #Siri your new iPhone butler. Click the link and be amazed by all it can do: http://t.co/lvfFdCEL @Apple
# So I am using my work PC (NEVER EVER) to get a feel for it; it has the worst speakers ever!! @apple you have spoiled me!! #imamac
# I  @Apple http://t.co/a8on3IAa
# @apple just got the new iOS5 upgrade with iMessage...good luck surviving now @BlackBerry
# Loving #iOS5 !! #awesome @Apple
# RT @MattyRiesz: @kathrynyee You were right an iPhone is a must have. #addicted {WELCOME TO THE @APPLE CLUB}
# Thank you @apple for your innovations. Exhibit A: Guy playing with Facetime instead of watching game at sports bar. http://t.co/oU7K39ge
# @blackberry boo hiss!............@apple wuhu!!!!!!!! When will my berry powered technology actually work??
# @apple by far the best iPod and first time iPhone ever.... Good job guys
# Thank you Steve @apple store 5th av. http://t.co/nSAisriP
# @Apple's Siri is witchcraft.  What's next @googleresearch. 2 yr lead lost?
# @Apple iOS 5 is sweet! Notifications phone search covers mail now wifi sync iCloud backup and integrated Twitter are all well done.
# RT @katebetts: Another great James Stewart story in today's NY Times about importance of architecture in @apple retail success http://t. ...
# Another great James Stewart story in today's NY Times about importance of architecture in @apple retail success http://t.co/Kniz452s
# I &lt;3 @apple http://t.co/ondXWpEr
# Welcome to the twitter world @MarkStuver. This is due to #iOS5 and @apple thanks guys.
# Impressive service @apple genius bar metro centre. Power cable replaced free n booked in for screen replacement for free :- D
# RT @deb_lavoy: the nice guy at the @apple store replaced my phone gratis when I showed him the hairline  crack on the screen. thanks @apple
# the nice guy at the @apple store replaced my phone gratis when I showed him the hairline  crack on the screen. thanks @apple
# My iPhone 4S battery lasted longer than a day. That hasn't happened since my edge iPhone. Nice job @apple.
# It would have taken me 15 mins to write this with my #Blackberry. Thank u @Apple 4s for converting me and showing me the grass is greener!
# RT @herahussain: @RickySinghPT got a new backside for my eye phone! V impressed with @apple
# @RickySinghPT got a new backside for my eye phone! V impressed with @apple
# #iPhone 4S in Space http://t.co/jINNHVwz this is amazing #creative @apple your products inspire people to do unbelievable things
# Thank you @apple for making my iPad 2 feel like new again with your new iOS 5!
# _ibertaddigital.tv/ iPad a briliant SteveJobs produck http://t.co/00ohfLY6@Apple present... http://t.co/DBbWSDpx
# Using my awsome iPad... I love it. I love my MacBook too and my iPod. It's all amazing! I love @apple
# @apple iOS 5 upgrade done ...... Much better feature..... Few more feature required
# New iOS 5 update is THE BEST. iloveyou @apple
# Finally got my iPhone 4S thanks @Apple. Stupid @att. Learned my lesson.
# I absolutely love my iPhone 4S. Thank you Steve and @apple.
# @apple - you have invented a product that actually gets my brother to call my parents when he gets where he's going. Amazing. #siri #ipod4s
# dammit listening to siri is making me want to upgrade. well played @apple.
# Create new folders from within your photo album in #iOS5 finally!! Thanks @Apple that's been a thorn in my side for a while. #newfeature
# Video card on @Kimaris workstation died after just six months. So long @hp. Hello @apple.
# @Blackberry & @Facebook U R really about to make me throw this @Blackberry in the trash an get an @Apple iPhone! @Facebook upload issues!
# #iOS5 update submitted to @apple! Thanks for all the support!
# Awesome service from the @apple store in pc. Thanks chris!
# RT @To1ne: .@apple thanks for fixing this... http://t.co/wTj1ogDO
# I am crazy about #iOS5 . The photo cropping is the best! @apple
# .@apple thanks for fixing this... http://t.co/wTj1ogDO
# Hell yes!!! Got my contacts back!!  Thanks @apple
# RT @SawyerHartman: I FU*KING LOVE YOU @APPLE this phone is the best thing ever !! SIRI = BEST THING EVER MADE
# @apple has changed life.
# Mad props to the @apple employee that didn't charge me to replace the back plate on my iPhone! Made my day!
# @jonsibley Actually the @Apple  mouse is pretty sweet man.
# The #iphone4s is  amazing. Siri's voice recognition is absolutely a step above previous attempts. Bravo @apple
# Finally got the @apple IPhone thanks to @sprint getting with the times
# #iOs5 is nice and as it had to be ! Thanks @Apple
# Good support fm Kevin @apple #Bellevue store 4 biz customers TY!
# Just downloaded IOS 5. It's better than I expected! #thankyou @apple
# Wow I am loving this new @apple update for my touch. #coolness Well done
# @Apple: Siri is amazing!!! I'm in love!
# Love love love iOS 5!! @apple
# RT @cjwallace03: So apparently @apple put MB cap on your SMS with the new update. 25mb storage before it tells you your inbox is full. W ...
# RT @Jewelz2611 @mashable @apple iphones r 2 expensive. Most went w/ htc/galaxy. No customer loyalty w/phone comp..
# @mashable @apple iphones r 2 expensive. Most went w/ htc/galaxy. No customer loyalty w/phone comp..
# THiS IS WHAT WiLL KiLL APPLE http://t.co/72Jw4z5c RiP @APPLE
# @apple why my tunes no go on my iPhone? iPhone lonely without them. silly #iOS5
# @apple needs to hurry up and release #iTunesMatch
# Why is  #Siri always down @apple
# I just need to exchange a cord at the apple store why do I have to wait for a genius? @apple
# @apple AirDrop #fail - Immediate declined your request. every time
# good article about why @apple fucked it all up with lion and their future. http://t.co/zNDP9Vr6 #fb
# RT @radlerc: Yellowgate? Some iPhone 4S Users Complain of Yellow Tint to Screen http://t.co/uaqrxTNk @apple @iphone4s
# Yellowgate? Some iPhone 4S Users Complain of Yellow Tint to Screen http://t.co/uaqrxTNk @apple @iphone4s
# The one #iphone feature still missing since @apple first showed it.. Contacts pictures on the contacts list! Simple yet 5 major updates miss
# Asked siri is she dreams of electric sleep. Was disappointed that she didn't have a snippy answer.  Missed opportunity @apple
# @paulens It surprises me that @Apple throws up an error alert about authorizing and there's no Authorize this computer button.
# @Lisa_Marie1987 shhhh. the evil sith lords @apple may hear you ha!
# FUCK YOU @apple DIE IN A FUCKING BLAZE INFERNO.
# Oh @apple. Steve obviously had nothing to do with iPhoto as it's the perfect opposite of 'insanely great'. Get it fixed please.
# OMG @apple WHY THE FUCK DID YOU DELETE ALL MY MUSIC YOU DICKS
# @ryanbaldwin @apple So in iTunes I go Store -&gt; Authorise why doesn't it just auto-authorise it when I sign into iTunes? Grrrr...
# Seriously - I have absolutely no offing clue what @Apple means by authorization nor how to do it.
# Boy could @apple make it any harder to put my purchased music from the cloud on to my new macbook pro? You must authorize this computer
# shit shit shit. IOS5 update ate all my apps data and media just like @apple said it would. This is going to take some time to rebuild.
# . @apple & @AT&T u cannot tell me there isn't at least 1 64GB iPhone 4S in LA or Vegas!! Give me a fucking break!!!!
# Love @apple downloads. 4 hours and i-pad now wonky! #ripstevejobs #thenonsensepersists #neednewipadguide #fatfuckingchance
# Dear @apple My new Air is now a notbook since your update killed #wifi #bug #destroying #productivity
# I am so done with @Att and @apple 's profitering and lack of customer service so fucking down with both!!!
# It would be great If @Apple would send my new phone. #frustrated
# @apple thank you for ruining my 3GS with #iOS5. You've just turned my phone into an utterly useless pile of shit.
# @rogerweir no but I have the option of a  replacement iPhone 4s ?Not sure if I want one after having 2 duff iPhones.@O2 @iphone4s @apple
# So apparently @apple put MB cap on your SMS with the new update. 25mb storage before it tells you your inbox is full. What is this 2001?
# You know @apple It's been almost a week since I paid for iTunes Match I would really like to use it. Any ETA on a fix?
# removing all @apple shit.
# So @PhoenixSwinger 's iPhone 4 is giving her a hella hard time w/ the iOS5 update @apple
# What??? I that sucks hello @apple RT @PhoneDog_Aaron Interesting note - DROID RAZR's battery isn't removable.
# @Apple can't send me an iPhone preordered 1hr after launching but they cans send 5 or 10 to all the jackasses who want to shoot or blend 'em
# Gotta say the @Apple itouch iphone shuffle etc.. sound quality is AWFUL.. painfully crap. Its been a downgrade from @Sony sound quality wise
# @bisquiat @Apple the upgrade just slows down my phone so much it's stuck half the time. uch. thankfully no other damage. sucks for you :(
# @Mayati I think @Apple didn't do such a thorough job with the step x steps for upgrade and move to iCloud. Now it's cost me mightily.
# Hey @apple now I have iOS5 my iPhone doesn't include songs that are on compilation albums under the artist's name. #whaddupwitdat
# @NickTheFNicon He can send but not rcve txts so he has an apt @apple at 4pm.Then he exclaims: And I waited a whole YEAR for this phone!!LMAO
# Total chaos at @apple store regent street. Like an Ethiopian feeding station. Can't believe this is same co. that makes all that cool shit.
# @FishMama: If you made a purchase just wait for the @apple survey! hate going b/c of the bad #custserv
# Correction: @ Best Buy kudos to Chris @ Alamo Ranch S.A. TX-fixed issues couldn't resolve after 1/2 day w/ @ATT & @Apple. Hero of my day!
# @phxguy88 @Apple @BGR That's why all the ppl who stand in line for hrs to get the newest model are suckers...
# Would it kill @apple to put a braille type bump on their earbuds so we know which bud is R and L in the dark.
# @APPLE Wow @MOTOROLA Just crushed your dreams....
# RT @phxguy88: Oh just fuck you @apple. Already?? ---&gt;  iPhone 5 on schedule for summer launch? http://t.co/Ofh9PTaG via @BGR
# Oh just fuck you @apple. Already?? ---&gt;  iPhone 5 on schedule for summer launch? http://t.co/Ofh9PTaG via @BGR
# @apple No I won't wait until thursday for an available appointment just so a 'genius' can tell me I'm shit out of luck. #now
# WTF?!?! @apple the new iOS 5 doesn't allow you NOT to get push notifications from newstand? and SIRI just keeps yapping FUCK!
# @Apple on the #iPad with #iOS5 why has the Messages Icon been included when it can't be used?
# @Steelo254 yea! I pre-order through @apple and they sorry too just like #AT&T
# Interesting... @apple now requires you to have a reservation ?         #apple #iphone #4S    :  http://t.co/zZK4fTii
# @apple why is my iPhone battery so crappy #fail
# My @Apple @macbook keyboard will not type :(
# Why doesn't @apple iCloud sync Stickies? They've always been around just nothing every progressed w/ them!! Why apple why?  @gruber
# @apple your new Save a Version function in Pages is absolutely the most awful interrupting counter-intuitive piece of crap in the world
# I hate my @apple computer.  Thats 3500 dollars down the drain.
# @apple my iPhone is charging very slowly!!!!!
# @Apple #iOS5 gm on ipad1 is very slow wash better on beta7/8 solve this problem or give me the ipad2
# @apple Wish I could pick month day and YEAR when setting a new calendar item on my iPhone. Why hasn't the new iOS fixed this yet?!
# @Apple iTunes is the worst program ever. For such a great phone you make some awful software.
# One would think the voice recognition on the @apple tech support line would work a little better.
# @apple $319 to repair my iPad 2 Apple you've lost me and my $700 a year Android here I come!
# @azee1v1 @apple @umber Proper consolidation proper syncing stop losing my PURCHASED items checkboxes that do what you think they will do.
# @AsimRang @apple @umber the desktop app is wack though
# I made a reservation and yet I still have to wait in line. Humpt! Oh @apple (@ Apple Store w/ 2 others) http://t.co/JZmVBdNm
# Frustrated that I bought a new macbook pro from @apple only to find it doesnt ship with media! #expensivepaperweight
# Dear @apple. I had to turn off all those awesome featured you just enabled. Data plan can't handle it. 200 mb of data just because #
# #DontBeMadAtMeBecause #Android is by far better than @Apple
# @apple is there a problem with iOS 5 that is preventing audio apps and audio functions from operating properly? I keep losing sound.
# @apple #apple One thing I hater about this #mouse the #buttery finish so fast am not #happy now #macworld @macworld http://t.co/5Uh4a4Vt
# Hey @Apple: stop sending your automatically-depreciate-all-iPhones-older-than-the-4s signal. My #iPhone4 is dying rapidly processor-wise.
# Only thing bad about the new @canon camera is that it has two compact flash cards... not one of SD. SD goes in my @apple computer. Damn you!
# Wtf @apple 64 pages for the new terms & conditions when u update ur apps from the iTunes store. Do u really think we'll read em? Really???
# fuck u @apple
# oh and prolly ganna be late to work bc @apple has screwed me and my phone has my only alarm on it
# why the fuck dose my phone decide its just ganna freeze every time i try to update it so fucking sick of @apple
# . if u need me just text me o wait u i wont get it cuz @apple fucks me every time #fuckingpissed
# iMessage doesn't show the time a message was sent annoying @apple
# Like @apple da fuck is this shit?  http://t.co/nb4DHlSg
# RT @CircusTK: I'm wit chu!! @ShayDiddy: Officially boycotting @ups!!! Calling @apple to curse them out next for using them wasting my t ...
# Damn it @Apple!! Whatchu done to my phone??
# Samsung seeks iPhone 4S ban in Japan and AustraliaPatent war intensifies with injunction sought against @Apple http://t.co/QmwjTvnk
# @apple why is it every time there is iOS software update my iPad goes dead and I need to totally restore? #fail
# @apple #iOS.5 has been nothing but a pain in the ass no room for my music.. Or photos.. Or apps! Can I undo this garbage??
# @apple the reservation system not working shows no products avail let alone iphone 4s I had the site open in 3 browsers at 9 PM and nothing
# RT @RedDeerSteph: @Joelplane @apple I hear you! I've had trouble with my 3 & now 4. I've even turned down brightness. #andshuttingdownru ...
# @Joelplane @apple I hear you! I've had trouble with my 3 & now 4. I've even turned down brightness. #andshuttingdownrunningprograms #nohelp
# @albertmal88 remember @apple is evil. #icloud entering the #dropbox market
# I know a few others having same issue RT @Joelplane: 9% now on my second full charge of the day. Pissed @Apple
# 9% now on my second full charge of the day. Pissed @Apple
# RT @ShayDiddy: @CircusTK @ups @apple both of them are bs!!! How do u tell me go between a certain time ONLY and the muh fuh is closed!
# I'm wit chu!! @ShayDiddy: Officially boycotting @ups!!! Calling @apple to curse them out next for using them wasting my time!
# ugh! @apple youre reservation page for the iPhone is NOT working.
# iTunes is @apple's worst product. Worse than the #Newton or the hockey puck mouse. It's utterly painful to use.
# Der iCloud I HATE U  AND I HOPE YOU DIE  YOU ARE THE WORST FUCKING INVENTION IN THE WORLD  FUCK YOUUUUUUUUUUUU #iCloud @apple @stevejobs
# i update to ios 5 and lose everything on my phone and it wont let me sign into my itunes account... thanks @Apple
# Suddenly lost all address book on @3GS iPhone. And someone was using my @Apple ID. It all fucked up.
# oh.. my iphone is overcapacity huh?! -____-  @Apple won't let me be great!!!
# Issues with updating iTunes on my windows pc - they really are not compatible.... Sent more time talking to @Apple care than using it!!
# @apple u guys are gay
# Restored my iPhone. STILL NO TEXTS. DEAR @APPLE Y NO LOVE Y RESTRICTIONS ON MY SMS?  Y NO TEXTS.... #iOS5 #iOS5atemydingo
# none of my apps work after the new ios from @apple. what do i do?!?
# Seemingly endless loop of calls to @apple @ups @verizonwireless to investigate my missing #iphone4s. #crankywithnophone
# @Wisconsin_Mommy @apple that's terrible!  I hope you get an apology!
# @zombiebomber have been on the phone with @verizonwireless and @apple pretty much ever since then. Really annoyed.
# @chascouponmom @apple I get they are busy w/ the new phone but I just wanted to buy a stylus. they made me wait forever outside & never
# @apple @iphone Please deliver my daughter's i4s she is driving me nuts #iphone
# @sprint @bestbuy still no word on my iPhone4s preorder.  Best Buy blames Sprint Sprint blames @apple I just want an honest answer.  #help
# Hey @apple the SMS full message is complete shit. Yes I'm annoyed.
# Have never had such poor customer service at @Apple before! What happened? (@ Apple Store w/ 2 others) http://t.co/GKlXMUi6
# @Apple your service experience is really fucking slipping (except for cute eyelash batting girlies). (@ Apple Store) http://t.co/dOHDEnMg
# Had ma Ipas not 24 hours an I jailbroke it...now its SHAGGED itunes won't letme restore it @apple SYM!!!!
# @hailfire101 @Irvysan They are... then @apple happened and snatched Siri so they could be douchebags and say 'it's ours!'
# What was @apple thinking making #Siri totally dependent on a network connection? Siri + @ATT = utter frustration.
# Wow the Genius Bar Reservation Line @Apple is ridic right now - ___- I am not amused. #ugh
# Where is my iPhone!?!?!?!@apple
# @apple battery life suck on iOS 5
# An apple update has seemed to render my work machine incapable of opening HDV video. Thanks @Apple. Zero useful productivity today.
# @apple I committed to your cloud storage iDisk and now it's raining :-( so soon no more iDisk.  Any plans for a new service for storage?
# Hey @apple why can't I share a reminder list from my iPhone?Also why can't I login to the iCloud webpage to modify sharing from my phone?
# Apparently fuzzball crashes on #iOS5. Congratulations @apple on another incompatible upgrade
# could @apple lion please integrate vertical spaces in mission control. this horizontal business is making me nauseous
# Can someone plz explain to me whhyy @apple is only distributing 2-3 phones per day to the sprint stores. I'm really ... http://t.co/uf9taK8f
# GAH. @apple iOS 5 opens text messages painfully slow on top of 3 restore attempts 2 succeed. Early adopterness gets better of me.
# Dear @apple: Why did all my PDFs and ePub files disappear from ibooks in my iPhone post ios5 upgrade? This hurts. #3GS #needsomethingtoread
# @CBM: Lies @apple. the battery on this new iPhone4S is definitely not any better. &lt;&lt; check Settings: 8 times more App usage in iOS 5
# As a huge podcast fan - I really feel like @Apple dropped the ball on this one. http://t.co/wvzPrbCI via @Carrypad
# I don't really like Siri's voice. Perhaps @apple can get Star Wars voices just like @garmin http://t.co/pSUJg9pN
# @carlton858: I really hate dealing with the brain dead people at the @apple store. For such good products customer service sucks. in NZ?
# I really hate dealing with the brain dead people at the @apple store. For such good products customer service sucks.
# You can make photo albums in the Photos app with iOS 5 but can't password protect them? Um... @apple fix that. Quickly.
# Anyone else seeing missing signal bars on their #iPhone 3GS with an upgrade to #iOS5? cc/ @applecanada @apple @forstall
# RT @CBM: Lies @apple. the battery on this new iPhone4S is definitely not any better.
# @apple If you want to know what customers think dont send updates with the noreply return address. Who invented that anyway. #useless
# Every time I try the voice control on my iPod Touch to send an iMessage it starts playing Who Knew by Pink.  Still not Flawless @Apple
# should be studying/ doing work but no I'm hold with @apple HURRY THE FUCK UP! #nopatience
# Ok Hindi keyboard in #iOS5 is something to cheer about.  But @apple  what about  support for 20+ missing Indian languages!? #FAIL
# RT @ScottDugas: Warning: if iphone apps spontaneously loose data it might not be the app's fault - http://t.co/1SEsvWwm #ios5downgrade  ...
# @betweensundays Ah! Yeah...should be an option...hopefully @apple figures that out. Thx
# Waiting for items to copy in Itunes after everything DID copy goes on and on and on.  Come on @Apple what the hell?
# @Apple unhappy again with service/product quality. Won't buy @Apple again.
# Lies @apple. the battery on this new iPhone4S is definitely not any better.
# @philipgrey: dear @apple why you gotta go change the way &lt;input type=number&gt; is handled out of the blue?
# Been on hold with @apple customer service for 25 minutes. Wow lt's like they're #timewarnercable.
# anyone else stuck in duped calendar/mail/battery sucking @apple hell? #iCloud and #OSX Lion are a disappointment
# For being the inventor of the computer mouse  Why is it that @Apple has never made one that is not a complete piece of fucking shit?!!?
# @Apple you're killing me. Excited about iOS5 no longer- tragic battery drain genius bar wants to replace the battery. Really?
# 1st impressions  of #iOS5- Disappointed w upgrade restore. Lot of apps & folders missing @apple do  how much time went in2 orging it? #fail
# @PrJusto Don't question the @Apple they will remember your dissent!
# @apple: Multiple times siri is having trouble connecting to the network.  Siri needs servers (and some exercise!)
# So my iMessage still isn't working! @apple
# RT @JimMcNiel: if @apple does not resolve the #Siri network issues they will need to rename a great product to Sorri - Who else is havin ...
# dear @apple why you gotta go change the way &lt;input type=number&gt; is handled out of the blue?
# Ugh. WTF is up with all the bottlenecks @paypal @apple?
# +1  RT @Doug_Newton: @apple PLEASE FIX #Siri!!!! She can't connect to your network!!!!!!!
# @apple PLEASE FIX #Siri!!!! She can't connect to your network!!!!!!!
# if @apple does not resolve the #Siri network issues they will need to rename a great product to Sorri - Who else is having issues?
# any chance @apple will release good headphones that dont blast music outside the ears? #iphone #ipod its quite obnoxious
# @Apple - #Siri is not working due to network problem? Seriously? Can you fix this? #iPhone4s #Fail
# @trisha_ps @iCloud is Cloudy. @apple tech not very techy.
# @electricsoup It has to connect to @Apple to process commands which it is failing to do right now
# See @Apple that what's happen when you release iPhone 4S with same crappy design as the old phone!
# This. RT @bonkoif Looks like @Apple did not appropriately project the resources needed for Siri. Not very reliable
# Looks like @Apple did not appropriately project the resources needed for Siri. Not very reliable
# Spoke to an @Apple rep on phone & could hear her tv blaring in the bg.  She said I can't actually help u just direct u back to the web
# What's wrong with Siri today @apple
# @Apple Siri is down!
# I'm suspecting @Apple timed the health-decline of my iPhone 4 perfectly with the iPhone 4s release... My battery is seriously ailing.
# on hold for another half hour. phone is ringing but no one is picking up.@apple you stink.
# Ok this @Apple software update for the #iphone is taking waaaaay too long!#annoyed
# @Apple would do better to inform customers properly about migrating to #iCloud - many complaints lead to #image damage http://t.co/QL7zmPpO
# @apple does iOS 5 rape your battery life? or am I just using my phone a lot since getting it
# @jane73 @Gazmaz hopefully it's a small bug @Apple must be fixing it. RIGHT  APPLE }:0( #itjustworks
# @samsung @apple you do realise you're just really pissing off the customer base AS WELL AS looking petty.
# @Apple - why do I have to have apps I am updating in their original 'folder' location? That was painful.
# @apple domain fail. Open 2 hrs late for walk in ppl. Store was empty and i only need a skin 4 my screen. You represent customer service FAIL
# @BrianMincey @apple the chipsets tear through battery life. Coworker has a htc thunderbolt that he gets about 3 hours of life.
# I wish the Apple updater would stop trying to ram iTunes down my throat. I don't own a pissing iPhone @apple
# Is it me or does my #iPhone run slower since the #iOS 5 update? @apple @Verizon
# Just searching with my voice on my 2 year old nexus one @apple.
# @apple your update server has been timing out for a week. i had to force a restore w/the new #iOS5 software. lost all my stuff. thanks!
# #appleupdates2 success stories- iPhone & iPad 2.Now been on phone to Apple 45 mins. iPad 1 WILL not. Wasting my time @apple#Replaceit!
# Thanks to a 90 minute wait on hold half an hour actually talking to someone the @Apple tech decides to send me an email to fix my phone
# I am very upset about and inconvenienced by this iphone update failed backup. @iphone @apple
# but seriously @apple finance me a damn phone you greedy bastards! OR Santa...get your jolly ass in gear and get us a 4S - white plz
# My schedule is 2 busy 2 spend UNquality time with @ATT @Apple 2 recover Iphone again-The mo' mobile I get the mo' immobile I is. Sync Not!
# Pondering the iOS update... From the sounds of @MikeFerri's difficulties I may just hold off :/ @Apple FIX IT!
# @twalve @apple you know the issues they have with DST and alarms :p
# Why book @Apple Genius Bar if after 2.5 hours you still can't be served. Disappointing Apple Store Sydney. #thanksfornothing
# Apparently @Apple genius training doesn't extend to clocks & service. They're half an hour late for my appointment and couldn't let me know?
# screw you @apple iOS 5. I can't download this crap and I'm tired of trying. Get this problem figured out about my connection timing out
# Wow. iCloud's mail is down. 1st the iOS 5 upgrade issues and now this. I really hope this isn't @apple without Steve Jobs.
# @apple  why don't you guys test your upgrades before you put them out. 15 1/2 hrs u guys wasted of my time yesterday. Thanks.
# what is going on with all my @Apple products?! First my #iPad freezes (still is frozen) and then my #iPhone won't turn on!!! #techieTroubles
# #iPad in perpetual restore loop after trying to upgrade to #iOS5 :(@apple sux without steve
# 2nd @apple genius apptment running late 2nd day in row for 2nd dodgy iPod . You make mega $$$ hire some staff.
# It took @apple about 7 years just to figure out how to properly syncronize an iPhone.  WOW!  #ios5
# @apple So I went to the 5th Ave store and was told I could wait about 4 hours to get a 4S. Needless to say I'm back at the hotel relaxing.
# Overall I am a fan of the iPhone 4S; however my Siri has issues connecting to the network @Apple
# Terrible customer service at Los Gatos @Apple! Why do I have to pay $199 for a bad home button on my iPhone?!?
# @Apple thank you for sucking so much. I cannot believe you would sell something online that isn't made
# Having major battery drain issue since updating iPhone 4 to iOS 5.  Anyone else? @AppStore @iPhone @apple
# Dear @apple please send me my Mac Book back surely the repair is done by now... Thanks!
# @apple thanks for ios5 - loving having my music breaking up like I'm talking on a mobile (cell) phone. Bring back functional 4 #iosdonwgrade
# @Apple #iOS5 on iPhone2 causes Camera apperature dilation problems & freeze.
# @Apple #iOS5 #geolocation Suburbs with 2 words drops Map Pins in other States! Please fix.
# Sorry @apple but #iMessage will never be what #BBM is. Disappointed.
# Iphone 4s siri doesn't work for shit @apple
# Clarence Thomas must have designed the new OSX lion tossing decades of workflow standards @apple bring back save as! #autoSaveSucks
# i officially HATE @apple... fix your damn itunes.
# Dear @apple your staff at the Little Rock store answered my first 3 questions with I don't know. they weren't hard questions.
# @semilshah yeah except that when you ask for a receipt it takes them 30 minutes to figure out where it printed out. Fix that @Apple!
# RT @JDougyJ: hey @apple do you wanna fix my fucking playlist order you piece of shit
# Bummer!  My @Yahoo! iPad fantasy football app keeps crashing; not sure if it's the app or the new @apple iOS 5. Only two apps running.
# @Apple can suck my dick gotta restore my ipad #annoyed
# The line at the @apple is just STUPID
# @nansen Man that sux! @apple io5 upgrade a total #fail for you!
# Dear @Apple Contacts you are terrible. I just cleaned duplicates for 3 hours and they magically reappeared. Fix it.
# Is it too much to ask which app is incompatible @apple? http://t.co/yKqip7nk
# Pissed with whoever designs keyboards with @apple for not having a home and end key.  working on the CLI i use those keys often
# @NoVaTyler @apple Most of mine are gone too! Not recovered after I saved them b4 I upgraded my iPhone! Soooo pissed!
# hey @apple do you wanna fix my fucking playlist order you piece of shit
# Siri is having a hard time remembering who my sister is. contact card needs space for family info. #iPhone4S @apple
# #ios5 getting sloppy @apple. U need to check your QA team. Too many issues with apps data and syncing
# RT @nansen: so this SMS full message is known @apple issue with new iOS5 update. trying restore. When all else #fail - restore.
# So glad that I paid $69 for this @apple care protection plan.  Been on hold for over 20 minutes now.  Great customer service. #NOT
# not happy with @apple right now. the upgrade to my itouch4 took out my itouch and laptop. #help
# All I can say about @Apple right now is #GoodRiddance  See? Cancer isn't ALL BAD!
# @twitter can you look at problem on iPad where it won't open @ messages. It just crashes the app. You too @apple maybe your fault.
# @apple What's the point of iCloud wireless updates when ios5 now forces me to use the computer to charge my ipod touch now? #worstupdateever
# @robert_terpstra no worries bud ps: they're saying that the 4s is having a lot of network issues right now. (I'm @apple for mac problems)
# I hate you @apple for not sending Toledooh @bestbuy any @iPhone for @verizon even after I pre ordered!!!
# @pmphillips @apple If my non-Apple equipment broke this often I guess I'd need an Asus genius bar. But it doesn't so I don't :-)
# Why is the new @apple iPhone OS duplicating all my iCal events? There's 2 of everything. How do I fix it? (tried turning iCloud off)
# Dear @Apple how convenient/handy/thoughtful/smart that after iPhone #ios5 update you're apps won't work anymore! (none!!!) :( #gr%\mbl^.%)
# Hey @Apple...I know Steve Jobs died & all but my Twitter for iPad app keeps crashing...Fix it...NOW..please..lol -F.Light
# @apple not happy with Apple today. I did the suggested software update and now nothing works!!!
# Smashed yet another #iPhone screen. When are @apple gonna make the phone more durable!!! Tired of fixing it myself!!!
# IOS5 has one problem when i save someone in my contacts they don't show his nam becuz of the region/ +965 @apple #apple
# I sure as hell better be able to restore my calendar events. Terrible bug apple! @apple #icloud #anothericloudfail
# I really hate that @apple won't let you hide the Newsstand app or move it into a folder. It serves no purpose for me.
# Life was much easier when @apple and @BlackBerry were just fruits!
# @apple No location reminders on ipad2! That was the point of updating to iOS 5
# Comparing @Office #live with @google #apps and @apple #iCloud  I do not see #iCloud leading the crowd. Do you agree ?
# RT @MikeFerri: If @apple doesn't fix iOS5 this week I'm buying a droid #emptythreats
# Turns out my computer isn't as fixed as it is meant to be. Fuck you @Apple I'm going back to your Genius Bar to complain. #annoyed
# If @apple doesn't fix iOS5 this week I'm buying a droid #emptythreats
# @apple pls launch #Siri on iphone4 .. Disappointed after spending hours for upgrading to iOS5..
# @apple you can suck it you and your fucking iPhones better be glad it's all I like cause the service Is fucking terrible
# This is the first time I've been unhappy with any @apple product... Disappointed and the Internet seems as confused as I am right now.
# After a week or so with @Apple's #iOS5 I'm considering going back to #jailbroken 4.2 - same features as 5 plus more. Not as stable though.
# Had issues with #Siri reaching network today. Too many uses or my signal? @apple
# The new iOS5 completely failed at upgrading the phone. Now I'm stuck in this restore loop. Thanks @apple for wasting my day. Can i undo?
# Is it me or does #iPhone4s run a little warm sometimes? @apple
# @apple WTF why can we not add the newsstand to a folder?! We are already in your walled garden so please don't remind us of it.
# @apple just now seeing none of my Microsoft Office programs work anymore after Lion upgrade. Why??
# Dear @Apple I don't want the newsstand icon on my screen. #notcool
# @Blackberry does take better quality photos than @Apple iPhone though. I give them that! #photograhersEye
# Ok @iTunesMusic idk wth is up but after syncing my phone my album art is out of order! WTF @Apple!
# I wish Siri could tweet for me . @apple fix that .
# @apple I'm still waiting for you to deliver my phone to @sprint
# I will never purchase another @Apple product for the rest of my life. I am glad Steve Jobs is fucking dead. MAY YOU FUCKING ROT IN HELL!!!!!
# Thanks to @Apple my new iMac is a brick. I cannot re-install Lion and I cannot purchase it because it was installed by the former owner.
# Asked #Siri Where's Baby Lisa? and was told sorry I'm having trouble connecting to the network right now. @apple server fail. #ios5
# Only thing #iOS.5 has done is deleted my tiger woods game and made impossible to retrieve. Thanks @Apple!
# Damn you @apple for breaking wififofum! It continued to work in ios 4. Was one of my most used apps. Damn Apple's overbearing policies!
# yo @apple this update is a disaster
# Dear @AppleCongratulations I am suing my insurance company and you just managed to make it to the top of my shit list. #Ineedthosepictures
# Dear @Apple: You must let me turn off iCloud to save bandwidth and NOT delete EVERY document on my iPad. That's BULLSHIT!
# RT @JoelBurns: Dear @Apple it's me again. Thank for beautiful new iOS features. But I miss some of the old ones. Lk making calls & texts&gt;(
# By far the worst experience upgrading out of any version of iOS @apple #iOS5
# What happened? RT @xCuntNuggetx: Never purchasing another item from @apple.
# Never purchasing another item from @apple.
# RT @leiboaz: Wow worst @apple customer service experience ever. Arrogant and inept. Bad combo Biltmore Apple store.
# Wow worst @apple customer service experience ever. Arrogant and inept. Bad combo Biltmore Apple store.
# Hey guys at @Apple WTF is happening to #iPhone4 with #iOS5 suddenly fade to black and begin to vibrate continuously I had to reboot it
# @hbogo @apple - why don't you play nice and let me use HDMI from iPad?  Pretty lame.
# Warning: if iphone apps spontaneously loose data it might not be the app's fault - http://t.co/1SEsvWwm #ios5downgrade @apple @marcoarment
# and only the first 23 images in my Photo Roll made it over? Seriously @apple how did you fuck this up so much?
# @apple why does #iPhone4 plus #iOS5 equal half the battery life?
# @apple why isn't my iTunes updating? I just wanna update my iPhone to IOS5!!! Then iTunes says that it needs to update to do it. Then fails!
# Now @apple won't let me use credit on @iTunes unless I have a credit card. Should have told me when I redeemed the cards. Sound fair to you?
# @amandbrar @apple Siri has worked for me less than 10% of the time. If service doesn't improve by Monday I'm returning my iPhone 4S.
# @azrael: RT @DavideGori: And again #MobileMe is down. Issues when syncing accessing mail... is this a good premise for #iCloud? @Apple ...
# need @apple help!! installing new ios on #iphone4 and am stuck on the Find My iPhone screen :( i keep clicking next but it doesn't work
# Bummer that @Apple #iCloud syncs on Windows only w/ Outlook (not Thunderbird) & IE (not Firefox Chrome). #sadmac
# Disappointing visual merchandising @apple. Simple but lacks elegance. And sequence doesn't even tell us about #Siri. http://t.co/XV2q3gfi
# has been on terminal hold with @apple support!  She must not be the only person having trouble with the new iphone and synching!
# @apple thanks apple for ios 5 and losing all my contacts!
# @apple give me my apps back!!!
# @Apple #iOS5 NONSTOP DROPPED CALLS&MUTE BUTTON RANDOMLY ACTIVATING&PERSON CANT HEAR ME PULL PHONE FROM EAR TO BE ON A MOBILE ME SCREEN
# RT @tomcolontonio: Didn't it occur to @apple #apple that ppl share iTunes accounts amongst family's ?????Wtf!!!!
# @tomcolontonio @apple #EPICFAIL
# 90 minutes after being at 100% my iPhone 4 (post #ios5 upgrade) has lost 40% of its charge and the @apple store folks are out of ideas.
# So cutting the cord makes podcasts even harder to manage?!? No subscriptions! WTH @Apple? http://t.co/LD2i871x #iOS5 (via @carrypad)
# In less than an hour my post- #iOS5 iPhone has gone from 100% to 73% battery charge and the @apple store folks have no solution for me :(
# Well @apple seems 2b screwing #iphone 4s resellars. They still dont have 4s. Yet were promised. Similar 2 Ma Bell's monopolistic prctices?
# Also @EricGreenspan don't forget @Apple stop closing the app store after each bloody purchase...
# @apple cu
# *sigh* @apple store seems stumped what to do about my catastrophically bad battery life after upgrading to #ios5
# Hmmmm a lot of #Siri features don't work in Canada. Location and directions? Seriously @apple come on!
# @apple #siri can't connect to the network -- it's LESS useful that VoiceControl now... :(
# @apple took my Siri and made it exclusive to iPhone 4S  #SoRude
# total time on the phone with @apple: 1 hour 27 minutes. let's see how this goes.
# Waited in line for nothing fucking genius @Apple called an app for John not jean stop fucking up my name im not a French boy. #PCam ...
# Dear @apple One day you're going to release a version of iTunes that doesn't freeze more often than it works. One day.
# It's been 24hrs since I reported @ups theft of my iPhone and @apple has done nothing. No return call as promised. Nothing.
# This does not bode well. After charging all night my @Apple iPhone 4S has 25% battery after only 3hr off charger with no calls & light use
# Houston we have a problem!! My iPad has been restoring for 12+ hours after installing @apple IOS5. This can't be right....
# #Siri went down for a little while last night. Come on @apple! Get your shit together on this launch!
# @ford should have teamed up with @Apple instead of @microsoft to make this SYNC system in my new focus. Car is sweet SYNC is #EpicFail
# RT @gdcurry: Really @Apple?  What have you done to my iTunes now?  I can't click on Music Movies TV Shows or any playlists. I get a l ...
# DAMN YOU !!! @apple

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(data):
    for punctuation in string.punctuation:
        if punctuation != '@':
            data = data.replace(punctuation, ' ')
    return data

# %%
def remove_trailing(data):
    data = data.replace('@',' ')
    return data

# %%
import re

# %%
tweet_X_task1.head(50)
# Out:
#                                                  text
# 0   Now all @Apple has to do is get swype on the i...
# 1   @Apple will be adding more carrier support to ...
# 2   Hilarious @youtube video - guy does a duet wit...
# 3   @RIM you made it too easy for me to switch to ...
# 4   I just realized that the reason I got into twi...
# 5   I'm a current @Blackberry user little bit disa...
# 6   The 16 strangest things Siri has said so far. ...
# 7   Great up close & personal event @Apple tonight...
# 8   From which companies do you experience the bes...
# 9   Just apply for a job at @Apple hope they call ...
# 10  RT @JamaicanIdler: Lmao I think @apple is onto...
# 11  Lmao I think @apple is onto something magical!...
# 12  RT @PhillipRowntree: Just registered as an @ap...
# 13  Wow. Great deals on refurbed #iPad (first gen)...
# 14  Just registered as an @apple developer... Here...
# 15   ! Currently learning Mandarin for my upcoming...
# 16  Come to the dark side @gretcheneclark: Hey @ap...
# 17  Hey @apple if you send me a free iPhone (any v...
# 18  Thank you @apple for Find My Mac - just locate...
# 19  Thanks to @Apple Covent Garden #GeniusBar for ...
# 20                     @DailyDealChat @apple Thanks!!
# 21  iPads Replace Bound Playbooks on Some N.F.L. T...
# 22                                  @apple..good ipad
# 23                  @apple @siri is efffing amazing!!
# 24  Amazing new @Apple iOs 5 feature.  http://t.co...
# 25  RT @TripLingo: We're one of a few Featured Edu...
# 26  We're one of a few Featured Education Apps on ...
# 27  When you want something done right you do it y...
# 28  We did an unexpected workshop for the #iPhone4...
# 29                                 &lt;3 #ios5 @apple
# 30  --- RT @Apple No question bro. RT @AintEeenTri...
# 31  RT @imightbewrong: I'm OVER people bitching ab...
# 32  I'm OVER people bitching about the #iPhone4S.....
# 33  @Twitter CEO points to @Apple as 'corporate me...
# 34           At the bus with my iPhone ;) thxx @apple
# 35  @azee1v1 @apple @umber AppStore is well done s...
# 36  NYTimes: Coach Wants to See You. And Bring You...
# 37  @apple @jilive @DanielPink: Apple sells 4 mill...
# 38              @bkad5161 than apologize to @apple ;)
# 39  @Apple downloads of iOS 5 are proving popular ...
# 40  Lmfao look at the argument I had with Siri !!@...
# 41  Incredible: 4 million iPhone 4Ss in 3 days. 13...
# 42  Save me from #HP's unwanted OS! Help me buy an...
# 43  Well @apple fixed my #ios5 battery drain probl...
# 44  Currently ordering a BRAND NEW MACBOOK PRO!!! ...
# 45                         you are so blessed. @apple
# 46  #Siri now knows who my dad mom brother and gir...
# 47  Well at least the @apple store has amazing cal...
# 48  #sweet... #apple replaced my glass #probono. t...
# 49  Not Bad! @Apple Sells Over 4 Million #IPhones ...

# %%
import nltk

# %%
xCount = None

# %%
def preprocessing(data):
    """
    Perform preprocessing of the tweets

    Args:
        data : list of tweets
    
    Returns: data: preprocessed list of tweets
    """
    data['text'] = data['text'].replace(to_replace=r'http://t\.co/[A-Za-z0-9]{8}',value=" ",regex=True)
    data['text'] = data['text'].str.lower()
    data['text'] = data['text'].apply(remove_punctuation)
    data['text'] = data['text'].replace(to_replace = r'@[A-Za-z0-9]*',value = 'AT_TOKEN',regex=True)
    data['text'] = data['text'].apply(remove_trailing)
    xCount = data['text']
    data['text'] = data['text'].apply(nltk.word_tokenize)
    return data
    
tweet_X_task1=preprocessing(tweet_X_task1)
tweet_X_task2=preprocessing(tweet_X_task2)

# %%
tweet_X_task1
# Out:
#                                                   text
# 0    [now, all, AT_TOKEN, has, to, do, is, get, swy...
# 1    [AT_TOKEN, will, be, adding, more, carrier, su...
# 2    [hilarious, AT_TOKEN, video, guy, does, a, due...
# 3    [AT_TOKEN, you, made, it, too, easy, for, me, ...
# 4    [i, just, realized, that, the, reason, i, got,...
# ..                                                 ...
# 474  [houston, we, have, a, problem, my, ipad, has,...
# 475  [siri, went, down, for, a, little, while, last...
# 476  [AT_TOKEN, should, have, teamed, up, with, AT_...
# 477  [rt, AT_TOKEN, really, AT_TOKEN, what, have, y...
# 478                              [damn, you, AT_TOKEN]
#
# [479 rows x 1 columns]

# %% [markdown]
# ## Step 3: Feature Extraction
# For feature extraction you  will  need  a  way  of  mapping  from  sentences  (lists  of  strings)  to  featurevectors, a process called feature extraction or featurization.<br>
# For feature vectors we will explore four techniques:
# <ul>
#     <li><b>Unigram feature vector</b>
#         <br> This will be a sparse vector with length equal to the vocabulary size.   It is sparse because a sentence generally contains only 20-40 unique words, so only this many positions in the vector will be nonzero.
# </li><br>
#     <li><b>Bigram feature vector</b><br>
#     The number of unique bigrams will be significantly lower that unigrams, but this will also be sparse.</li><br>
#     <li><b>POS features</b>
#     Instead of using the words we will use POS tags, this will be generally not as sparse as unigram and bigram, you can use nltk to get POS tags for a sentence, here the featurevectors length will be equal to the total number of unique POS tags.</li><br>
#     <li><b>Complex features</b>
#     These can be a combination of unigrams and bigrams or any other complex feature that you can think of, we will explore these in later part of the assignment.</li><br>
# </ul>
#
# Firstly we need the extract the vocabulary for each of these different feature vectors.<br>
# For this task use [nltk](https://www.nltk.org/)

# %%
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter
from nltk.tag import pos_tag

# %%
def converter(df,n=0,pos=False):
    tempSet = set()
    for val in df['text']:
        if n==1:
            for subval in val:
                tempSet.add(subval)
        elif n>1:
            ngramss = (list(ngrams(val,n)))
            for subval in ngramss:
                tempSet.add(subval)
        elif pos==True:
            tags = pos_tag(val)
            for tag in tags:
                tempSet.add(tag)
    return list(tempSet)

# %%
def vocabulary_unigram(data):
    """
    Returns list of unique unigrams

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique unigrams
    """
    return (converter(data,1))
    
    
def vocabulary_bigram(data):
    """
    Returns list of unique bigrams

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique bigrams
    """
    return converter(data,2)
def vocabulary_POS(data):
    """
    Returns list of unique POS tags

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique POS tags
    """
    return converter(data,pos=True)
    
vocab_unigram_task1=vocabulary_unigram(tweet_X_task1)
vocab_bigram_task1=vocabulary_bigram(tweet_X_task1)
vocab_pos_tag_task1=vocabulary_POS(tweet_X_task1)

vocab_unigram_task2=vocabulary_unigram(tweet_X_task2)
vocab_bigram_task2=vocabulary_bigram(tweet_X_task2)
vocab_pos_tag_task2=vocabulary_POS(tweet_X_task2)

# %%
vocab_unigram_task1
# Out:
# ['health',
#  'overall',
#  'bottom',
#  'apparently',
#  'voice',
#  'this',
#  'carrier',
#  'throws',
#  'impressed',
#  'cutting',
#  'invention',
#  'p',
#  'hear',
#  'probono',
#  'apt',
#  'ours',
#  'in2',
#  'best',
#  '69',
#  'glass',
#  'there',
#  'mo',
#  'were',
#  'inbox',
#  'will',
#  'lot',
#  'regent',
#  'last',
#  'galaxy',
#  'covers',
#  'sucking',
#  'using',
#  'who',
#  'owns',
#  'loose',
#  'snippy',
#  'empty',
#  'policies',
#  'preventing',
#  'worse',
#  'almost',
#  'loss',
#  '700',
#  'harder',
#  'thorough',
#  'wth',
#  'did',
#  'plate',
#  'sounds',
#  'fb',
#  'card',
#  'japan',
#  'so',
#  'order',
#  'now',
#  'located',
#  'cool',
#  'eggs',
#  'magically',
#  'listening',
#  'hong',
#  'sith',
#  'occur',
#  'play',
#  'lack',
#  'need',
#  'terrible',
#  'wants',
#  'lead',
#  'way',
#  'newstand',
#  'garden',
#  'simple',
#  'service',
#  'wristpad',
#  'upgrade',
#  'experience',
#  'readinglists',
#  'an',
#  'reported',
#  'cloud',
#  'product',
#  'putting',
#  'retail',
#  'stylus',
#  'ps',
#  'smart',
#  'seeing',
#  '30',
#  'incapable',
#  'sigh',
#  'officially',
#  'swype',
#  'sucks',
#  'emptythreats',
#  'whaddupwitdat',
#  'dear',
#  'ppl',
#  'dreams',
#  'inept',
#  'served',
#  'lose',
#  'reboot',
#  'tonight',
#  'notbook',
#  'idk',
#  'thankyou',
#  'calling',
#  'died',
#  'distributing',
#  'training',
#  'terms',
#  'error',
#  'proving',
#  'h',
#  'yo',
#  'didn',
#  'type',
#  'tell',
#  'about',
#  'paid',
#  'painfully',
#  'working',
#  'sms',
#  'qa',
#  'replacing',
#  'they',
#  'da',
#  'pcam',
#  'screwed',
#  'offing',
#  'failed',
#  'enhance',
#  'figure',
#  'proper',
#  'butler',
#  'sprint',
#  'andshuttingdownrunningprograms',
#  'say',
#  'well',
#  'kind',
#  'investigate',
#  'spontaneously',
#  'spoiled',
#  'yessss',
#  'screwing',
#  '23',
#  'madness',
#  'uch',
#  'nam',
#  'playbooks',
#  'totally',
#  'w',
#  'buttery',
#  'needsomethingtoread',
#  '2012',
#  'hour',
#  'ram',
#  'andshuttingdownru',
#  'seemed',
#  'synching',
#  'updates',
#  'contact',
#  'do',
#  'r',
#  'name',
#  'plz',
#  'outlook',
#  'feel',
#  'issue',
#  'doesnt',
#  'someone',
#  'white',
#  'mobile',
#  'water',
#  'ma',
#  'bell',
#  'disappear',
#  'download',
#  '4g',
#  'focus',
#  'version',
#  'app',
#  'duped',
#  'lies',
#  'its',
#  'alamo',
#  'takes',
#  'air',
#  'removing',
#  'line',
#  'black',
#  'went',
#  'aaron',
#  'mentor',
#  'wuhu',
#  'interrupting',
#  'release',
#  'fuzzball',
#  'crashes',
#  '135',
#  'story',
#  'painful',
#  'worldwide',
#  'centre',
#  'sd',
#  'whatchu',
#  'site',
#  'non',
#  'popular',
#  'bg',
#  'installing',
#  'efffing',
#  'voicecontrol',
#  'setting',
#  'inform',
#  'folder',
#  'photo',
#  'sorry',
#  'just',
#  'itunesmatch',
#  'u',
#  'very',
#  'office',
#  'cell',
#  'txts',
#  'lacks',
#  'completely',
#  'thats',
#  'wife',
#  'briliant',
#  'remembering',
#  '7',
#  'apptment',
#  'asked',
#  'try',
#  'iosdonwgrade',
#  '9',
#  'dammit',
#  'meant',
#  'mute',
#  'evo',
#  'servers',
#  'option',
#  'everything',
#  'your',
#  'braille',
#  'open',
#  'st',
#  'being',
#  'far',
#  'one',
#  'mega',
#  'number',
#  'undo',
#  'closing',
#  'cardsapp',
#  'see',
#  '4pm',
#  'definitely',
#  'art',
#  'featured',
#  'disaster',
#  'wiped',
#  'pages',
#  '16',
#  'destroying',
#  'too',
#  'bummer',
#  'pls',
#  'i',
#  'itjustworks',
#  'launching',
#  'ie',
#  'worth',
#  'needs',
#  'annoyed',
#  'ipod4s',
#  'promised',
#  'idisk',
#  'bar',
#  'rt',
#  'points',
#  'delete',
#  'missing',
#  'home',
#  'however',
#  'suspecting',
#  'surprises',
#  'take',
#  'handled',
#  'write',
#  'direct',
#  '3hr',
#  'um',
#  'wont',
#  'hello',
#  'morning',
#  'complain',
#  'agree',
#  'checkboxes',
#  'stumped',
#  'pissed',
#  'sorude',
#  'education',
#  'side',
#  'help',
#  'argument',
#  'importance',
#  'rock',
#  'comparing',
#  'apologize',
#  'electric',
#  'it',
#  'turning',
#  'hoping',
#  'rcve',
#  'should',
#  'nor',
#  'makes',
#  'overcapacity',
#  'complaints',
#  'reminders',
#  'duff',
#  'street',
#  'mightily',
#  'that',
#  'amused',
#  'witchcraft',
#  'saved',
#  'eyelash',
#  'bullshit',
#  'compilation',
#  'suburbs',
#  'lame',
#  'model',
#  'think',
#  'force',
#  'studying',
#  'paying',
#  'booked',
#  'purchased',
#  'millenia',
#  'replaceit',
#  'ship',
#  'upgrades',
#  'haha',
#  'called',
#  'ordered',
#  'tossing',
#  'duet',
#  'canada',
#  'photos',
#  'workstation',
#  'updating',
#  'apply',
#  'exhibit',
#  'stink',
#  'admit',
#  'would',
#  'keeps',
#  'trouble',
#  'goes',
#  'hasn',
#  'warning',
#  'ios5downgrade',
#  'are',
#  'sorri',
#  'though',
#  'faster',
#  'read',
#  'really',
#  'combo',
#  'here',
#  'user',
#  'garbage',
#  'continuing',
#  'chaos',
#  'man',
#  'os',
#  'expensivepaperweight',
#  'survey',
#  'yourdaysarenumbered',
#  'bloomberg',
#  'geolocation',
#  'dead',
#  'smartphone',
#  'tried',
#  'dodgy',
#  'cap',
#  'avail',
#  'huh',
#  'baby',
#  'mention',
#  'restrictions',
#  'of',
#  'models',
#  'hiss',
#  'stewart',
#  'messages',
#  'custserv',
#  'people',
#  'useless',
#  'must',
#  'razr',
#  'resources',
#  'compatible',
#  'subscriptions',
#  'committed',
#  'teams',
#  'return',
#  'star',
#  'magical',
#  'info',
#  'trip',
#  'something',
#  'equipment',
#  'location',
#  'stand',
#  'looks',
#  'his',
#  'slipping',
#  'waaaaay',
#  'continued',
#  'right',
#  'rename',
#  'programs',
#  'pay',
#  'company',
#  'music',
#  'longer',
#  'thunderbird',
#  'local',
#  'meet',
#  'sports',
#  'apology',
#  'awsome',
#  'total',
#  'at',
#  '20',
#  'event',
#  'forces',
#  'nicki',
#  'registered',
#  'much',
#  'thievingbastards',
#  'phones',
#  'remind',
#  'within',
#  'laptop',
#  'my',
#  'architecture',
#  'document',
#  'offers',
#  'actually',
#  'replacement',
#  'original',
#  'red',
#  'answer',
#  'integrate',
#  'pro',
#  'finally',
#  'explain',
#  'pre',
#  'nohelp',
#  'hard',
#  'rice',
#  'neednewipadguide',
#  'protect',
#  'stable',
#  'eta',
#  'biltmore',
#  'hire',
#  'arrogant',
#  'kudos',
#  'standards',
#  'correction',
#  'dis',
#  'lisa',
#  'safari',
#  'brain',
#  'feeding',
#  'i4s',
#  'techietroubles',
#  'moving',
#  'ok',
#  'gods',
#  'appstore',
#  'equivalent',
#  'gets',
#  'starts',
#  'request',
#  'machine',
#  'impressions',
#  'gr',
#  'cuz',
#  '3x',
#  'knew',
#  'fail',
#  'represent',
#  'night',
#  'fuck',
#  'have',
#  'stuck',
#  'backside',
#  '0',
#  'cancer',
#  'keep',
#  'damage',
#  'save',
#  'iphoto',
#  'giving',
#  'dark',
#  'obnoxious',
#  'poor',
#  'expensive',
#  'vertical',
#  'bus',
#  'learned',
#  'crappy',
#  'she',
#  'ipads',
#  'iphones',
#  'blend',
#  'ideas',
#  'same',
#  'unhappy',
#  'thoughtful',
#  'horizontal',
#  'personal',
#  'syncronize',
#  'updater',
#  'reliable',
#  'spoke',
#  'fu',
#  'each',
#  'hold',
#  'b',
#  'instead',
#  'bound',
#  'plans',
#  'biz',
#  'piece',
#  'thomas',
#  'purpose',
#  'incompatible',
#  'terpstra',
#  'doing',
#  'unreal',
#  'awesome',
#  'make',
#  'her',
#  'mail',
#  'bc',
#  'beyond',
#  'rapidly',
#  'deleted',
#  'vegas',
#  '15',
#  'fuh',
#  'present',
#  'apple',
#  'worked',
#  'long',
#  'gave',
#  'which',
#  'first',
#  'sux',
#  'luck',
#  'crashing',
#  'smartest',
#  '76',
#  'noreply',
#  'where',
#  'server',
#  'apperature',
#  'keyboard',
#  'wireless',
#  'io5',
#  'insurance',
#  'except',
#  'preordered',
#  'lock',
#  'charging',
#  'share',
#  'recover',
#  'flash',
#  'merchandising',
#  'also',
#  'tone',
#  'upload',
#  'walled',
#  'jailbroken',
#  'until',
#  'consolidation',
#  'flawless',
#  'laid',
#  'bought',
#  'compact',
#  'drain',
#  'album',
#  'talking',
#  '1',
#  'little',
#  '24',
#  'decide',
#  'freezes',
#  'lords',
#  't',
#  'leopard',
#  'coworker',
#  'bode',
#  'vibrate',
#  'perfectly',
#  'grass',
#  'especially',
#  'blackberry',
#  'lion',
#  'sick',
#  'exclusive',
#  'honored',
#  'duplicating',
#  'sync',
#  'damaged',
#  'trash',
#  'gone',
#  'don',
#  'newest',
#  'properly',
#  'asus',
#  'body',
#  'ur',
#  'half',
#  'fault',
#  'chris',
#  'handle',
#  'rest',
#  'throw',
#  'browsers',
#  'brother',
#  'another',
#  'ical',
#  'y',
#  'signups',
#  'onto',
#  'attempts',
#  'wonky',
#  'come',
#  'sells',
#  'downloads',
#  'data',
#  'i0s5',
#  'sloppy',
#  'fuckingpissed',
#  'removable',
#  'woods',
#  'dropped',
#  'ny',
#  'replace',
#  'useful',
#  'check',
#  '25mb',
#  'clocks',
#  'worstupdateever',
#  'jobs',
#  'overbearing',
#  'gigs',
#  'told',
#  'sooo',
#  'times',
#  'believe',
#  'activating',
#  'slows',
#  'huge',
#  'rip',
#  'profitering',
#  'imamac',
#  'utter',
#  'timing',
#  'gen',
#  'step',
#  'gratis',
#  'clicking',
#  'orging',
#  'cu',
#  'refurbed',
#  'yeah',
#  'blue',
#  'schedule',
#  'youre',
#  '3500',
#  'macbook',
#  'mommy',
#  'ring',
#  '2001',
#  'macosc',
#  'apps',
#  'n',
#  'day305',
#  'without',
#  'tear',
#  'greedy',
#  'av',
#  'slide',
#  'lavoy',
#  'dontbemadatmebecause',
#  'invested',
#  'include',
#  'premise',
#  'sent',
#  '2nd',
#  'due',
#  'princessofchina',
#  's',
#  'wish',
#  'enabled',
#  'hand',
#  'know',
#  'migrating',
#  'bless',
#  'autosavesucks',
#  'rva',
#  'james',
#  'resolve',
#  'facetime',
#  'opening',
#  'ios5',
#  'whores',
#  'making',
#  'failing',
#  'dilation',
#  'wise',
#  '4',
#  'dst',
#  'going',
#  '4ss',
#  'beautiful',
#  'hdv',
#  'fucked',
#  'disappointing',
#  'down',
#  'der',
#  'previous',
#  'anymore',
#  'hairline',
#  'keys',
#  '1hr',
#  'chipsets',
#  'worst',
#  'cant',
#  'message',
#  '3d',
#  '965',
#  'send',
#  'tech',
#  'point',
#  'storage',
#  'ass',
#  'droid',
#  'podcast',
#  'months',
#  'exchange',
#  'gatos',
#  'relaxing',
#  'included',
#  'sure',
#  'iloveyou',
#  'lovemyiphone',
#  'newfeature',
#  'wait',
#  'ipad2',
#  'current',
#  'restored',
#  'guess',
#  'today',
#  'bahhh',
#  'reappeared',
#  'bug',
#  'durable',
#  'lost',
#  'required',
#  'case',
#  'slower',
#  'notjustaboutthephone',
#  'repair',
#  'nuts',
#  'guys',
#  'lt',
#  '5th',
#  'lonely',
#  'http',
#  'sense',
#  'kill',
#  'time',
#  'live',
#  'corporate',
#  'imessage',
#  'two',
#  'breaking',
#  'showed',
#  'sending',
#  'parents',
#  'wash',
#  'word',
#  'frustration',
#  'bottlenecks',
#  'future',
#  '27',
#  'reason',
#  'update',
#  'b4',
#  'thanks',
#  'hide',
#  'cracked',
#  'such',
#  'technology',
#  'automatically',
#  'awful',
#  'improve',
#  'sadmac',
#  'hockey',
#  'appointment',
#  'push',
#  'products',
#  'others',
#  'anyway',
#  'their',
#  'account',
#  'o',
#  'battery',
#  'mouse',
#  'connection',
#  'suck',
#  'usage',
#  'millions',
#  'surviving',
#  'monday',
#  'find',
#  'metro',
#  'la',
#  'many',
#  'ganna',
#  'im',
#  'available',
#  'productivity',
#  'artist',
#  'worries',
#  'change',
#  'loyalty',
#  'market',
#  'booted',
#  'moment',
#  'touch',
#  'appleupdates2',
#  'killed',
#  'thunderbolt',
#  'million',
#  'playing',
#  'amongst',
#  'camera',
#  'hypo',
#  'bud',
#  'keyboards',
#  'wifi',
#  'contacts',
#  'running',
#  'having',
#  'lol',
#  'outside',
#  'in',
#  'was',
#  'spend',
#  'lmfao',
#  'him',
#  'picking',
#  'wasted',
#  'authorize',
#  'debut',
#  'iphone2',
#  'ios5atemydingo',
#  'month',
#  'edge',
#  'welcome',
#  'ceo',
#  'gb',
#  'slowly',
#  'backchannel',
#  'tx',
#  'alive',
#  'adopterness',
#  'etc',
#  'up',
#  'reservation',
#  'team',
#  'other',
#  'buying',
#  'can',
#  'gear',
#  'king',
#  'together',
#  'won',
#  'trying',
#  'miss',
#  'beta7',
#  'thanksfornothing',
#  'amazing',
#  'often',
#  'hurry',
#  'yet',
#  'houston',
#  'please',
#  'means',
#  'realise',
#  'says',
#  'had',
#  'humor',
#  'how',
#  'rot',
#  'against',
#  'thank',
#  'yr',
#  'dick',
#  'tweet',
#  'accounts',
#  'by',
#  'war',
#  'what',
#  'begin',
#  'questions',
#  'key',
#  'screw',
#  'ban',
#  'downloaded',
#  'pile',
#  'set',
#  'obviously',
#  'alarm',
#  'nexus',
#  'c',
#  'goodriddance',
#  'steps',
#  'managed',
#  'stop',
#  'AT_TOKEN',
#  'stolen',
#  '365daysofgratefulness',
#  'has',
#  'iphone',
#  'lunch',
#  '1st',
#  'ringing',
#  'book',
#  'makemeproud',
#  'looking',
#  'job',
#  'credit',
#  'surely',
#  'early',
#  'doesn',
#  'under',
#  'those',
#  'hut',
#  'tragic',
#  'somehow',
#  'nonstop',
#  'iphone4',
#  'started',
#  'immobile',
#  'we',
#  'workshop',
#  '3gs',
#  'power',
#  'control',
#  'ipod',
#  'address',
#  'girlfriend',
#  'to',
#  'could',
#  'succeed',
#  'lolol',
#  'amount',
#  'ever',
#  'care',
#  'ethiopian',
#  'earbuds',
#  'covent',
#  'took',
#  'appletv',
#  'cord',
#  'getting',
#  'sweet',
#  'immediate',
#  'seriously',
#  'syncing',
#  'wififofum',
#  'nz',
#  'ipad1',
#  'die',
#  'mad',
#  'year',
#  ...]

# %%
vocab_bigram_task1
# Out:
# [('man', 'do'),
#  ('be', 'studying'),
#  ('good', 'job'),
#  ('i', 'sent'),
#  ('submitted', 'to'),
#  ('day', 'and'),
#  ('another', 'half'),
#  ('kong', 'i'),
#  ('iphone', 'ios5'),
#  ('ios5', 'battery'),
#  ('some', 'staff'),
#  ('took', 'my'),
#  ('apps', 'running'),
#  ('i', 'save'),
#  ('is', 'now'),
#  ('are', 'on'),
#  ('through', 'battery'),
#  ('wish', 'the'),
#  ('4s', 'has'),
#  ('asus', 'genius'),
#  ('AT_TOKEN', 'put'),
#  ('texts', 'thanks'),
#  ('making', 'me'),
#  ('this', 'garbage'),
#  ('ios5', 'the'),
#  ('12', 'hours'),
#  ('which', 'it'),
#  ('conditions', 'when'),
#  ('did', 'there'),
#  ('sorry', 'too'),
#  ('buy', 'a'),
#  ('million', 'via'),
#  ('pretty', 'bad'),
#  ('recover', 'iphone'),
#  ('backchannel', 'AT_TOKEN'),
#  ('to', 'say'),
#  ('software', 'lost'),
#  ('mobile', 'devices'),
#  ('ios5', 'finally'),
#  ('studying', 'doing'),
#  ('air', 'smallvictory'),
#  ('post', 'card'),
#  ('former', 'owner'),
#  ('siri', 'so'),
#  ('expensive', 'most'),
#  ('i', 'share'),
#  ('man', 'loving'),
#  ('it', 'i'),
#  ('he', 'exclaims'),
#  ('is', 'this'),
#  ('pins', 'in'),
#  ('never', 'made'),
#  ('take', 'some'),
#  ('i', 'absolutely'),
#  ('address', 'book'),
#  ('hut', 'hut'),
#  ('awsome', 'ipad'),
#  ('corporate', 'mentor'),
#  ('and', 'move'),
#  ('it', 'serves'),
#  ('using', 'cloud'),
#  ('version', 'of'),
#  ('awesome', 'amount'),
#  ('mention', 'for'),
#  ('air', 'is'),
#  ('two', 'compact'),
#  ('me', 'mightily'),
#  ('a', 'disaster'),
#  ('words', 'drops'),
#  ('you', 'play'),
#  ('windows', 'pc'),
#  ('suburbs', 'with'),
#  ('playlist', 'order'),
#  ('want', 'an'),
#  ('has', 'issues'),
#  ('quality', 'is'),
#  ('me', 'nauseous'),
#  ('smashed', 'my'),
#  ('settings', '8'),
#  ('network', 'AT_TOKEN'),
#  ('rcve', 'txts'),
#  ('4s', 'sorude'),
#  ('andshuttingdownrunningprograms', 'nohelp'),
#  ('happy', 'with'),
#  ('AT_TOKEN', 'unless'),
#  ('connecting', 'to'),
#  ('do', 'AT_TOKEN'),
#  ('post', 'ios5'),
#  ('alamo', 'ranch'),
#  ('an', 'email'),
#  ('going', 'back'),
#  ('c', 'of'),
#  ('319', 'to'),
#  ('imessage', 'will'),
#  ('pro', 'you'),
#  ('this', 'new'),
#  ('a', 'free'),
#  ('i', 'll'),
#  ('my', 'computer'),
#  ('nexus', 'one'),
#  ('wont', 'let'),
#  ('goes', 'on'),
#  ('who', 'else'),
#  ('them', 'um'),
#  ('tech', 'not'),
#  ('now', 'this'),
#  ('removing', 'all'),
#  ('needed', 'for'),
#  ('burn', 'my'),
#  ('AT_TOKEN', 'hey'),
#  ('glad', 'it'),
#  ('mega', 'hire'),
#  ('case', 'has'),
#  ('AT_TOKEN', 'terpstra'),
#  ('service', 'from'),
#  ('skin', '4'),
#  ('had', 'and'),
#  ('and', 'on'),
#  ('hear', 'you'),
#  ('ass', 'no'),
#  ('all', 'my'),
#  ('it', 'doesn'),
#  ('sent', 'my'),
#  ('charge', 'me'),
#  ('is', 'witchcraft'),
#  ('AT_TOKEN', 'hurry'),
#  ('and', 'inconvenienced'),
#  ('forever', 'outside'),
#  ('easy', 'for'),
#  ('list', 'ineedthosepictures'),
#  ('i', 'give'),
#  ('the', 'blue'),
#  ('my', 'album'),
#  ('ve', 'even'),
#  ('years', 'old'),
#  ('happened', 'and'),
#  ('john', 'not'),
#  ('repair', 'my'),
#  ('phone', 'a'),
#  ('to', 'reboot'),
#  ('issue', 'with'),
#  ('and', 'opening'),
#  ('sticking', 'it'),
#  ('events', 'terrible'),
#  ('that', 'isn'),
#  ('one', 'AT_TOKEN'),
#  ('AT_TOKEN', 'one'),
#  ('AT_TOKEN', 'sells'),
#  ('even', 'tell'),
#  ('would', 'think'),
#  ('was', 'talking'),
#  ('ios', '4'),
#  ('unhappy', 'with'),
#  ('the', 'newton'),
#  ('of', 'mine'),
#  ('your', 'dreams'),
#  ('hairline', 'crack'),
#  ('productivity', 'today'),
#  ('guys', 'test'),
#  ('purchase', 'it'),
#  ('store', 'in'),
#  ('AT_TOKEN', 'contacts'),
#  ('happy', 'camper'),
#  ('terpstra', 'no'),
#  ('if', 'after'),
#  ('the', 'reason'),
#  ('definitely', 'not'),
#  ('1hr', 'after'),
#  ('a', 'fan'),
#  ('yeah', 'AT_TOKEN'),
#  ('aaron', 'interesting'),
#  ('fixed', 'please'),
#  ('team', 'too'),
#  ('printed', 'out'),
#  ('up', 'like'),
#  ('AT_TOKEN', 't'),
#  ('in', 'line'),
#  ('the', 'wash'),
#  ('cuz', 'AT_TOKEN'),
#  ('no', 'more'),
#  ('just', 'stupid'),
#  ('5', 'rape'),
#  ('success', 'stories'),
#  ('and', 'l'),
#  ('is', 'kind'),
#  ('about', 'ios5'),
#  ('my', 'daughter'),
#  ('since', 'AT_TOKEN'),
#  ('crack', 'iphone'),
#  ('on', 'ipad2'),
#  ('update', 'for'),
#  ('think', 'they'),
#  ('staff', 'at'),
#  ('with', 'whoever'),
#  ('amazing', 'i'),
#  ('often', 'i'),
#  ('my', 'windows'),
#  ('off', 'AT_TOKEN'),
#  ('domain', 'fail'),
#  ('congratulations', 'AT_TOKEN'),
#  ('restore', 'loop'),
#  ('another', 'item'),
#  ('your', 'simply'),
#  ('AT_TOKEN', 'unhappy'),
#  ('love', 'my'),
#  ('and', 'again'),
#  ('5', 'on'),
#  ('email', 'to'),
#  ('still', 'the'),
#  ('iphone', 'AT_TOKEN'),
#  ('time', 'uch'),
#  ('as', 'hell'),
#  ('4ss', 'in'),
#  ('hear', 'it'),
#  ('got', 'a'),
#  ('fail', 'open'),
#  ('3', 'AT_TOKEN'),
#  ('iphone4s', 'iphone'),
#  ('has', 'arrived'),
#  ('AT_TOKEN', 'lion'),
#  ('from', 'newstand'),
#  ('the', 'support'),
#  ('the', 'ball'),
#  ('how', 'much'),
#  ('t', 'do'),
#  ('t', 'get'),
#  ('and', 'get'),
#  ('efffing', 'amazing'),
#  ('m', 'a'),
#  ('a', 'truly'),
#  ('ever', 'to'),
#  ('told', 'me'),
#  ('like', 'at'),
#  ('ipad', '2'),
#  ('my', 'glass'),
#  ('it', 's'),
#  ('all', 'well'),
#  ('icloud', 's'),
#  ('i', 'hear'),
#  ('be', 'fuck'),
#  ('bitching', 'about'),
#  ('really', 'think'),
#  ('s', 'like'),
#  ('hope', 'they'),
#  ('up', 'and'),
#  ('camera', 'is'),
#  ('lacks', 'elegance'),
#  ('well', 'today'),
#  ('long', 'annoyed'),
#  ('were', 'just'),
#  ('go', 'to'),
#  ('developer', 'here'),
#  ('sound', 'quality'),
#  ('a', 'reminder'),
#  ('siri', 'on'),
#  ('investigate', 'my'),
#  ('love', 'affair'),
#  ('kill', 'AT_TOKEN'),
#  ('adopterness', 'gets'),
#  ('it', 'yourself'),
#  ('get', 'great'),
#  ('the', 'first'),
#  ('yo', 'AT_TOKEN'),
#  ('died', 'after'),
#  ('i', 'hope'),
#  ('i', 've'),
#  ('hate', 'going'),
#  ('remembering', 'who'),
#  ('love', 'ios5'),
#  ('inventor', 'of'),
#  ('his', 'nam'),
#  ('regent', 'st'),
#  ('phone', 'search'),
#  ('blackberry', 'thank'),
#  ('wait', 'forever'),
#  ('frozen', 'and'),
#  ('lion', 'tossing'),
#  ('ios', 'update'),
#  ('it', 'has'),
#  ('yellow', 'tint'),
#  ('store', 'after'),
#  ('switch', 'to'),
#  ('not', 'purchase'),
#  ('app', 'keeps'),
#  ('ta', 'hand'),
#  ('awesome', 'little'),
#  ('to', 'process'),
#  ('AT_TOKEN', 'pls'),
#  ('photo', 'roll'),
#  ('coolness', 'well'),
#  ('absolutely', 'love'),
#  ('phone', 'gratis'),
#  ('lavoy', 'the'),
#  ('upload', 'issues'),
#  ('for', 'cute'),
#  ('health', 'decline'),
#  ('subscriptions', 'wth'),
#  ('for', 'the'),
#  ('used', 'to'),
#  ('a', 'replacement'),
#  ('new', 'imac'),
#  ('tired', 'of'),
#  ('be', 'glad'),
#  ('r', 'really'),
#  ('AT_TOKEN', 'may'),
#  ('attempts', '2'),
#  ('i', 'guess'),
#  ('app', 's'),
#  ('something', 'to'),
#  ('actually', 'work'),
#  ('when', 'syncing'),
#  ('AT_TOKEN', 'simple'),
#  ('to', 'restore'),
#  ('AT_TOKEN', 'steve'),
#  ('i', 'really'),
#  ('crazy', 'about'),
#  ('suck', 'my'),
#  ('i', 'pad'),
#  ('t', 'believe'),
#  ('trouble', 'with'),
#  ('is', 'dying'),
#  ('AT_TOKEN', 'domain'),
#  ('with', 'injunction'),
#  ('stuff', 'thanks'),
#  ('new', 'air'),
#  ('i', 'went'),
#  ('bad', 'home'),
#  ('that', 'sucks'),
#  ('AT_TOKEN', 'for'),
#  ('iphones', 'in'),
#  ('4s', 'ban'),
#  ('all', 'the'),
#  ('took', 'AT_TOKEN'),
#  ('match', 'i'),
#  ('AT_TOKEN', 'get'),
#  ('you', 'and'),
#  ('disruptions', 'and'),
#  ('pretty', 'sweet'),
#  ('we', 're'),
#  ('now', 'seeing'),
#  ('buy', 'AT_TOKEN'),
#  ('i', 'did'),
#  ('on', 'phone'),
#  ('tell', 'me'),
#  ('computer', 'damn'),
#  ('so', 'done'),
#  ('reason', 'i'),
#  ('AT_TOKEN', 'airdrop'),
#  ('the', 'love'),
#  ('mac', 'book'),
#  ('yes', 'got'),
#  ('nuts', 'iphone'),
#  ('than', 'apologize'),
#  ('to', 'force'),
#  ('has', 'my'),
#  ('the', 'photos'),
#  ('let', 's'),
#  ('the', 'disruptions'),
#  ('the', 'mo'),
#  ('are', 'proving'),
#  ('had', 'such'),
#  ('itunes', 'grrrr'),
#  ('5', 'plus'),
#  ('are', 'not'),
#  ('it', 'surprises'),
#  ('does', 'iphone4s'),
#  ('promised', 'nothing'),
#  ('visual', 'merchandising'),
#  ('up', 'the'),
#  ('the', 'bottlenecks'),
#  ('i', 'haven'),
#  ('impressed', 'with'),
#  ('i', 'still'),
#  ('or', '10'),
#  ('show', 'his'),
#  ('re', 'just'),
#  ('made', 'me'),
#  ('orging', 'it'),
#  ('4', 'is'),
#  ('with', 'service'),
#  ('design', 'as'),
#  ('restore', 'my'),
#  ('little', 'bit'),
#  ('person', 'having'),
#  ('store', 'so'),
#  ('to', 'AT_TOKEN'),
#  ('old', 'i'),
#  ('5', 'AT_TOKEN'),
#  ('touch', 'now'),
#  ('AT_TOKEN', 'love'),
#  ('gratis', 'when'),
#  ('you', 'release'),
#  ('aside', 'from'),
#  ('for', 'you'),
#  ('mb', 'of'),
#  ('upgraded', 'her'),
#  ('phone', 'now'),
#  ('or', 'a'),
#  ('damaged', 'macbook'),
#  ('changed', 'my'),
#  ('they', 'could'),
#  ('in', 'other'),
#  ('what', 'do'),
#  ('compact', 'flash'),
#  ('reminders', 'on'),
#  ('25mb', 'storage'),
#  ('thanks', 'chris'),
#  ('regent', 'street'),
#  ('5', 'feature'),
#  ('eyelash', 'batting'),
#  ('lords', 'AT_TOKEN'),
#  ('hiss', 'AT_TOKEN'),
#  ('images', 'in'),
#  ('lmfao', 'look'),
#  ('have', 'the'),
#  ('might', 'not'),
#  ('1st', 'impressions'),
#  ('i4s', 'she'),
#  ('today', 'out'),
#  ('last', 'night'),
#  ('button', 'randomly'),
#  ('iphone4s', 'with'),
#  ('charge', 'of'),
#  ('a', 'pain'),
#  ('to', 'image'),
#  ('days', 'now'),
#  ('new', 'one'),
#  ('on', 'with'),
#  ('me', 'every'),
#  ('iphone', 'that'),
#  ('marie1987', 'shhhh'),
#  ('at', 'least'),
#  ('have', 'with'),
#  ('multiple', 'times'),
#  ('why', 'you'),
#  ('surviving', 'now'),
#  ('i', 'officially'),
#  ('outlook', 'not'),
#  ('is', 'nice'),
#  ('is', 'known'),
#  ('messages', 'painfully'),
#  ('name', 'im'),
#  ('AT_TOKEN', 'stop'),
#  ('ipad', 'i'),
#  ('goes', 'in'),
#  ('15', 'mins'),
#  ('still', 'have'),
#  ('the', '5th'),
#  ('guys', 'are'),
#  ('ios', 'fixed'),
#  ('for', 'my'),
#  ('parents', 'when'),
#  ('music', 'from'),
#  ('tonite', 'AT_TOKEN'),
#  ('27', 'minutes'),
#  ('huge', 'podcast'),
#  ('with', 'all'),
#  ('to', 'h'),
#  ('models', 'rt'),
#  ('so', 'in'),
#  ('it', 'blend'),
#  ('stumped', 'what'),
#  ('store', 'rt'),
#  ('very', 'nice'),
#  ('my', 'iphone'),
#  ('newton', 'AT_TOKEN'),
#  ('crashes', 'on'),
#  ('pay', '199'),
#  ('question', 'bro'),
#  ('wit', 'chu'),
#  ('iphone', 'shuffle'),
#  ('today', 'i'),
#  ('chaos', 'at'),
#  ('u', 'update'),
#  ('newsstand', 'icon'),
#  ('day', 'that'),
#  ('the', 'suggested'),
#  ('my', 'microsoft'),
#  ('crushed', 'your'),
#  ('is', 'going'),
#  ('great', 'customer'),
#  ('that', 'what'),
#  ('downloaded', 'ios'),
#  ('day', 'you'),
#  ('i', 'walk'),
#  ('happy', 'now'),
#  ('me', 'when'),
#  ('loving', 'having'),
#  ('AT_TOKEN', 'thank'),
#  ('been', 'around'),
#  ('wow', 'ios5'),
#  ('t', 'made'),
#  ('a', 'certain'),
#  ('really', 'annoyed'),
#  ('me', 'and'),
#  ('why', 'can'),
#  ('it', 'myself'),
#  ('sales', 'top'),
#  ('absolutely', 'the'),
#  ('then', 'going'),
#  ('line', 'would'),
#  ('since', 'my'),
#  ('got', 'my'),
#  ('AT_TOKEN', 'about'),
#  ('forward', 'to'),
#  ('credit', 'on'),
#  ('about', '7'),
#  ('causes', 'camera'),
#  ('ve', 'lost'),
#  ('all', 'bad'),
#  ('quality', 'photos'),
#  ('ios', 'features'),
#  ('android', 'here'),
#  ('just', 'announced'),
#  ('AT_TOKEN', 'loving'),
#  ('eggs', 'pull'),
#  ('opportunity', 'AT_TOKEN'),
#  ('perpetual', 'restore'),
#  ('offers', 'great'),
#  ('next', 'for'),
#  ('AT_TOKEN', 'said'),
#  ('i', 'get'),
#  ('not', 'any'),
#  ('was', 'much'),
#  ('2', 'hrs'),
#  ('any', 'version'),
#  ('think', 'AT_TOKEN'),
#  ('and', 'we'),
#  ('down', 'bar'),
#  ('microsoft', 'office'),
#  ('terms', 'conditions'),
#  ('to', 'totally'),
#  ('bug', 'destroying'),
#  ('retrieve', 'thanks'),
#  ('handle', 'it'),
#  ('itunes', 'that'),
#  ('again', 'the'),
#  ('s', 'battery'),
#  ('or', 'apps'),
#  ('laptop', 'help'),
#  ('i', 'think'),
#  ('out', 'how'),
#  ('no', 'worries'),
#  ('need', 'to'),
#  ('wants', 'to'),
#  ('more', 'app'),
#  ('life', 'coworker'),
#  ('f', 'light'),
#  ('stylus', 'they'),
#  ('bag', 'of'),
#  ('battery', 'drain'),
#  ('save', 'bandwidth'),
#  ('only', 'and'),
#  ('need', 'a'),
#  ('from', '100'),
#  ('4', 'days'),
#  ('word', 'wow'),
#  ('iphone4s', 'fail'),
#  ('about', 'AT_TOKEN'),
#  ('indian', 'languages'),
#  ('missing', 'indian'),
#  ('just', 'want'),
#  ('keys', 'often'),
#  ('product', 'to'),
#  ('million', 'iphone'),
#  ('get', 'the'),
#  ('AT_TOKEN', 'got'),
#  ('your', 'qa'),
#  ('what', 'the'),
#  ('AT_TOKEN', 'maybe'),
#  ('comparing', 'AT_TOKEN'),
#  ('have', 'ios5'),
#  ('4', 'i'),
#  ('address', 'who'),
#  ('lol', 'ring'),
#  ('using', 'my'),
#  ('i', 'try'),
#  ('your', 'walled'),
#  ('for', 'this'),
#  ('missing', 'AT_TOKEN'),
#  ('AT_TOKEN', 'wish'),
#  ('AT_TOKEN', 'putting'),
#  ('is', 'ringing'),
#  ('AT_TOKEN', 'instead'),
#  ('see', 'icloud'),
#  ('calls', 'texts'),
#  ('AT_TOKEN', 'man'),
#  ('s', 'see'),
#  ('back', 'to'),
#  ('that', 'quickly'),
#  ('or', 'any'),
#  ('AT_TOKEN', 'does'),
#  ('ppl', 'store'),
#  ('to', 'wait'),
#  ('try', 'to'),
#  ('fault', 'ios5downgrade'),
#  ('lt', 'lt'),
#  ('months', 'so'),
#  ('apparently', 'fuzzball'),
#  ('your', 'request'),
#  ('40', 'of'),
#  ('now', 'forces'),
#  ('should', 'i'),
#  ('flawless', 'and'),
#  ('is', 'magical'),
#  ('m', 'over'),
#  ('ie', 'not'),
#  ('are', 'unreal'),
#  ('hand', 'me'),
#  ('30', 'minutes'),
#  ('4', '2'),
#  ('icloud', 'and'),
#  ('thankyou', 'AT_TOKEN'),
#  ('exchange', 'a'),
#  ('means', 'by'),
#  ('why', 'AT_TOKEN'),
#  ('apperature', 'dilation'),
#  ('AT_TOKEN', 'workstation'),
#  ('the', 'bad'),
#  ('problem', 'figured'),
#  ('sith', 'lords'),
#  ('re', 'timewarnercable'),
#  ('miss', 'it'),
#  ('this', 'rt'),
#  ('has', 'done'),
#  ('to', 'your'),
#  ('see', 'ya'),
#  ('is', 'giving'),
#  ('2', 'year'),
#  ('the', 'card'),
#  ('in', 'perpetual'),
#  ('phone', 'frustrated'),
#  ('edge', 'iphone'),
#  ('shit', 'together'),
#  ('sent', 'annoying'),
#  ('to', 'write'),
#  ('compatible', 'sent'),
#  ('damn', 'itunes'),
#  ('slows', 'down'),
#  ('out', 'thx'),
#  ('the', 'jackasses'),
#  ('they', 'really'),
#  ('line', 'for'),
#  ('able', 'to'),
#  ('clocks', 'service'),
#  ('4s', 'siri'),
#  ('so', 'thankful'),
#  ('no', 'i'),
#  ('ios5downgrade', 'AT_TOKEN'),
#  ('gf', 'iphone4s'),
#  ('its', 'quite'),
#  ('every', 'progressed'),
#  ('siri', 'now'),
#  ('backside', 'for'),
#  ('sending', 'your'),
#  ('for', 'an'),
#  ('hear', 'her'),
#  ('told', 'sorry'),
#  ('gatos', 'AT_TOKEN'),
#  ('shows', 'no'),
#  ('now', 'thanks'),
#  ('time', 'went'),
#  ('is', 'deleted'),
#  ('lack', 'of'),
#  ('hour', 'phone'),
#  ('not', 'jean'),
#  ('some', 'awful'),
#  ('bad', 'ass'),
#  ('pissed', 'AT_TOKEN'),
#  ('were', 'very'),
#  ('now', 'all'),
#  ('incompatible', 'AT_TOKEN'),
#  ('think', 'it'),
#  ('i', 'go'),
#  ('fm', 'kevin'),
#  ('for', 'being'),
#  ('AT_TOKEN', 'fucked'),
#  ('battery', 'charge'),
#  ('AT_TOKEN', 'store'),
#  ('who', 'my'),
#  ('your', 'staff'),
#  ('that', 'is'),
#  ('for', '2nd'),
#  ('realized', 'that'),
#  ('AT_TOKEN', 'my'),
#  ('i', 'expected'),
#  ('service', 'so'),
#  ('are', 'already'),
#  ('worst', 'program'),
#  ('AT_TOKEN', 'getting'),
#  ('a', 'case'),
#  ('proving', 'popular'),
#  ('so', 'crappy'),
#  ('to', 'screen'),
#  ('hurry', 'up'),
#  ('4s', 'first'),
#  ('ceo', 'points'),
#  ('now', 'worstupdateever'),
#  ('actually', 'talking'),
#  ('read', 'em'),
#  ('s', 'utterly'),
#  ('that', 'cool'),
#  ('iphone', 'preordered'),
#  ('ma', 'bell'),
#  ('new', 'macbook'),
#  ('returning', 'my'),
#  ('texts', 'dear'),
#  ('so', 'much'),
#  ('photo', 'albums'),
#  ('been', 'nothing'),
#  ('io5', 'upgrade'),
#  ('now', 'geek'),
#  ('and', 'directions'),
#  ('so', 'cutting'),
#  ('finally', 'thanks'),
#  ('throat', 'i'),
#  ('laundering', 'ari'),
#  ('fixing', 'it'),
#  ('AT_TOKEN', 'right'),
#  ('madness', 'no'),
#  ('working', 'like'),
#  ('boo', 'hiss'),
#  ('4s', 'for'),
#  ('AT_TOKEN', 'really'),
#  ('just', 'downloaded'),
#  ('the', 'siri'),
#  ('s', 'cost'),
#  ('there', 'is'),
#  ('inbox', 'is'),
#  ('the', 'newest'),
#  ('right', 'apple'),
#  ('are', 'suckers'),
#  ('were', 'promised'),
#  ('not', 'bad'),
#  ('in', 'first'),
#  ('your', 'update'),
#  ('apps', 'damn'),
#  ('webpage', 'to'),
#  ('next', '4'),
#  ('the', 'best'),
#  ('itunes', 'store'),
#  ('my', 'edge'),
#  ('get', 'push'),
#  ('ask', 'which'),
#  ('apple', '0'),
#  ('is', 'AT_TOKEN'),
#  ('just', 'got'),
#  ('new', 'AT_TOKEN'),
#  ('9', 'now'),
#  ('message', 'was'),
#  ('t', 'own'),
#  ('dilation', 'problems'),
#  ('fixed', 'my'),
#  ('died', 'all'),
#  ('music', 'you'),
#  ('my', 'ios5'),
#  ('inspire', 'people'),
#  ('sms', 'with'),
#  ('a', 'folder'),
#  ('experience', 'is'),
#  ('bg', 'she'),
#  ('yet', 'i'),
#  ('awesome', 'service'),
#  ('me', 'buy'),
#  ('ate', 'all'),
#  ('no', 'subscriptions'),
#  ('hate', 'AT_TOKEN'),
#  ('iphone', 'lonely'),
#  ('why', 'don'),
#  ('service', 'AT_TOKEN'),
#  ('reaching', 'network'),
#  ('work', 'in'),
#  ('would', 'have'),
#  ('macosc', 'snow'),
#  ('an', 'get'),
#  ('admit', 'AT_TOKEN'),
#  ('bottlenecks', 'AT_TOKEN'),
#  ('s', 'me'),
#  ('new', 'focus'),
#  ('for', 'wasting'),
#  ('the', '16'),
#  ('need', 'an'),
#  ('4', '5yrs'),
#  ('ring', 'tone'),
#  ('AT_TOKEN', 'via'),
#  ('phone', 'but'),
#  ('authorization', 'nor'),
#  ('accounts', 'amongst'),
#  ('you', 'not'),
#  ('your', 'shit'),
#  ('does', 'not'),
#  ('m', 'back'),
#  ('after', 'lion'),
#  ('send', 'an'),
#  ('better', 'feature'),
#  ('absolutely', 'no'),
#  ('in', 'hell'),
#  ('for', 'ever'),
#  ('excited', 'about'),
#  ('mack', 'wan'),
#  ('from', 'middle'),
#  ('AT_TOKEN', 'would'),
#  ('fuzzball', 'crashes'),
#  ('was', 'sent'),
#  ('an', 'upgrade'),
#  ('desktop', 'app'),
#  ('few', 'featured'),
#  ('am', 'so'),
#  ('distributing', '2'),
#  ('facetime', 'instead'),
#  ('gon', 'na'),
#  ('gt', 'iphone'),
#  ('recognition', 'is'),
#  ('fucking', 'invention'),
#  ('the', 'nice'),
#  ('out', 'of'),
#  ('war', 'intensifies'),
#  ('overall', 'i'),
#  ('newton', 'or'),
#  ('42', 'red'),
#  ('works', 'one'),
#  ('s', 'why'),
#  ('AT_TOKEN', 'imac'),
#  ('iphones', 'r'),
#  ('store', 'why'),
#  ('incapable', 'of'),
#  ('m', 'tired'),
#  ('the', 'worldwide'),
#  ('quality', 'won'),
#  ('the', 'cord'),
#  ('AT_TOKEN', 'oh'),
#  ('now', 'the'),
#  ('my', 'android'),
#  ('na', 'fix'),
#  ('please', 'fix'),
#  ('time', 'there'),
#  ('interrupting', 'counter'),
#  ('m', 'thankful'),
#  ('any', 'better'),
#  ('some', 'iphone'),
#  ('hrs', 'late'),
#  ('is', 'driving'),
#  ('tell', 'us'),
#  ('that', 'actually'),
#  ('free', 'iphone'),
#  ('meant', 'to'),
#  ('receipt', 'it'),
#  ('your', 'ipad'),
#  ('honored', 'tonite'),
#  ('out', 'next'),
#  ('suddenly', 'fade'),
#  ('iphone', 'run'),
#  ('i', 'would'),
#  ('now', 'lol'),
#  ('when', 'you'),
#  ('kill', 'apple'),
#  ('would', 'really'),
#  ('time', 'i'),
#  ('AT_TOKEN', 'must'),
#  ('d', 'need'),
#  ('2', 'same'),
#  ('ma', 'man'),
#  ('smashed', 'yet'),
#  ('not', 'one'),
#  ('lt', 'check'),
#  ('they', 'magically'),
#  ('the', 'hairline'),
#  ('my', 'stolen'),
#  ('deals', 'on'),
#  ('you', 'still'),
#  ('phone', 'has'),
#  ('throw', 'this'),
#  ('from', 'ear'),
#  ('this', 'iphone4s'),
#  ('refurbed', 'ipad'),
#  ('or', 'move'),
#  ('she', 'dreams'),
#  ('at', '9'),
#  ('disappointing', 'apple'),
#  ('sloppy', 'AT_TOKEN'),
#  ('service', 'they'),
#  ('hand', 'it'),
#  ('girlfriend', 'is'),
#  ('wars', 'voices'),
#  ('fucking', 'playlist'),
#  ('debut', 'weekend'),
#  ('AT_TOKEN', 'messages'),
#  ('AT_TOKEN', 'only'),
#  ('no', 'authorize'),
#  ('just', 'registered'),
#  ('yet', '5'),
#  ('most', 'texts'),
#  ('it', 'would'),
#  ('me', 'or'),
#  ('want', 'to'),
#  ('sprint', 'stores'),
#  ('said', 'i'),
#  ('you', 'greedy'),
#  ('AT_TOKEN', 'server'),
#  ('to', 'use'),
#  ('programs', 'work'),
#  ('like', 'to'),
#  ('without', 'steve'),
#  ('must', 'be'),
#  ('AT_TOKEN', 'too'),
#  ('had', 'the'),
#  ('list', 'simple'),
#  ('a', 'receipt'),
#  ('boy', 'could'),
#  ('sequence', 'doesn'),
#  ('too', 'and'),
#  ('the', 'trash'),
#  ('those', 'keys'),
#  ('morning', 'man'),
#  ('wth', 'is'),
#  ('do', 'how'),
#  ('in', 'row'),
#  ('out', 'about'),
#  ('baby', 'lisa'),
#  ('it', 'won'),
#  ('after', 'each'),
#  ('network', 'issues'),
#  ('monday', 'i'),
#  ('icloud', 'i'),
#  ('all', 'night'),
#  ('here', 'iphone'),
#  ('with', 'updating'),
#  ('my', 'last'),
#  ('resolve', 'the'),
#  ('with', 'i'),
#  ('over', '4'),
#  ('bloody', 'purchase'),
#  ('full', 'message'),
#  ('this', 'up'),
#  ('the', 'little'),
#  ('backup', 'AT_TOKEN'),
#  ('powered', 'technology'),
#  ('of', 'a'),
#  ('lunch', 'break'),
#  ('missing', 'signal'),
#  ('no', 'this'),
#  ('suspecting', 'AT_TOKEN'),
#  ('fucking', 'dead'),
#  ('your', 'fucking'),
#  ('t', 'the'),
#  ('wow', 'the'),
#  ('phone', 'more'),
#  ('now', 'and'),
#  ('sm', 'rt'),
#  ('photo', 'cropping'),
#  ('2b', 'screwing'),
#  ('hold', 'half'),
#  ('AT_TOKEN', 'software'),
#  ('guy', 'at'),
#  ('sync', 'system'),
#  ('cloud', 'AT_TOKEN'),
#  ('5', 'only'),
#  ('AT_TOKEN', 'products'),
#  ('m', 'moving'),
#  ('protection', 'plan'),
#  ('the', 'ipad'),
#  ('and', 'icloud'),
#  ('looks', 'like'),
#  ('AT_TOKEN', 'ps'),
#  ('open', '2'),
#  ('steps', 'for'),
#  ('ibooks', 'in'),
#  ('my', 'battery'),
#  ('to', 'sticking'),
#  ('its', 'charge'),
#  ('apparently', 'AT_TOKEN'),
#  ('support', 'to'),
#  ('haha', 'siri'),
#  ('for', 'such'),
#  ('just', 'ganna'),
#  ('useful', 'productivity'),
#  ('for', 'your'),
#  ('phones', 'per'),
#  ('bud', 'ps'),
#  ('s', 'been'),
#  ('thx', 'AT_TOKEN'),
#  ('finance', 'me'),
#  ('ganna', 'freeze'),
#  ('965', 'AT_TOKEN'),
#  ('with', 'your'),
#  ('hella', 'hard'),
#  ('appointment', 'just'),
#  ('s', 'wrong'),
#  ('m', 'AT_TOKEN'),
#  ('to', 'curse'),
#  ('the', 'ios'),
#  ('be', 'thanks'),
#  ('just', 'wanted'),
#  ('was', 'AT_TOKEN'),
#  ('is', 'well'),
#  ('updates', 'with'),
#  ('education', 'apps'),
#  ('has', 'screwed'),
#  ('store', 'for'),
#  ('calling', 'AT_TOKEN'),
#  ...]

# %%
vocab_pos_tag_task1
# Out:
# [('pins', 'NNS'),
#  ('notbook', 'NN'),
#  ('re', 'VBP'),
#  ('changed', 'VBN'),
#  ('those', 'DT'),
#  ('sm', 'NN'),
#  ('come', 'VB'),
#  ('hate', 'JJ'),
#  ('icloud', 'JJ'),
#  ('isn', 'JJ'),
#  ('losing', 'VBG'),
#  ('forever', 'RB'),
#  ('sprint', 'NN'),
#  ('been', 'VBN'),
#  ('iphones', 'VBZ'),
#  ('less', 'RBR'),
#  ('busy', 'JJ'),
#  ('64gb', 'CD'),
#  ('charging', 'VBG'),
#  ('software', 'NN'),
#  ('hater', 'VBP'),
#  ('wash', 'NN'),
#  ('5th', 'JJ'),
#  ('which', 'WDT'),
#  ('loving', 'VBG'),
#  ('gt', 'JJ'),
#  ('nopatience', 'NN'),
#  ('received', 'VBD'),
#  ('redeemed', 'VBD'),
#  ('very', 'RB'),
#  ('thomas', 'NN'),
#  ('were', 'VBD'),
#  ('sound', 'JJ'),
#  ('freezes', 'NNS'),
#  ('vibrate', 'VB'),
#  ('dammit', 'NN'),
#  ('list', 'NN'),
#  ('stable', 'JJ'),
#  ('a', 'DT'),
#  ('hut', 'NN'),
#  ('devices', 'NNS'),
#  ('reported', 'VBD'),
#  ('bring', 'VB'),
#  ('tunes', 'NN'),
#  ('eyelash', 'NN'),
#  ('guy', 'NN'),
#  ('yourself', 'PRP'),
#  ('find', 'VB'),
#  ('available', 'JJ'),
#  ('seeing', 'VBG'),
#  ('sticking', 'VBG'),
#  ('freeze', 'VBP'),
#  ('sure', 'JJ'),
#  ('policies', 'NNS'),
#  ('call', 'NN'),
#  ('ineedthosepictures', 'NNS'),
#  ('bitching', 'VBG'),
#  ('mission', 'NN'),
#  ('ram', 'VB'),
#  ('loop', 'NN'),
#  ('thankful', 'JJ'),
#  ('lol', 'VBP'),
#  ('covent', 'NN'),
#  ('3d', 'CD'),
#  ('downgrade', 'NN'),
#  ('undo', 'JJ'),
#  ('help', 'VB'),
#  ('updates', 'NNS'),
#  ('stewart', 'VBP'),
#  ('u', 'JJ'),
#  ('stop', 'VB'),
#  ('returning', 'VBG'),
#  ('until', 'IN'),
#  ('work', 'VB'),
#  ('mbl', 'NN'),
#  ('guys', 'NNS'),
#  ('ios5atemydingo', 'NN'),
#  ('say', 'VB'),
#  ('s', 'NNS'),
#  ('snippy', 'JJ'),
#  ('apps', 'NN'),
#  ('n', 'NN'),
#  ('works', 'NNS'),
#  ('turns', 'VBZ'),
#  ('accounts', 'NNS'),
#  ('health', 'NN'),
#  ('glad', 'NN'),
#  ('ios', 'JJ'),
#  ('fuck', 'JJ'),
#  ('texts', 'JJ'),
#  ('here', 'RB'),
#  ('wiped', 'VBN'),
#  ('live', 'JJ'),
#  ('even', 'RB'),
#  ('tx', 'JJ'),
#  ('upgrade', 'JJ'),
#  ('want', 'VBP'),
#  ('lack', 'NN'),
#  ('allow', 'IN'),
#  ('itunes', 'NNS'),
#  ('headphones', 'NNS'),
#  ('batting', 'NN'),
#  ('sorri', 'VB'),
#  ('fail', 'VBP'),
#  ('nauseous', 'JJ'),
#  ('steps', 'NNS'),
#  ('try', 'NN'),
#  ('languages', 'NNS'),
#  ('ruining', 'VBG'),
#  ('declined', 'VBD'),
#  ('driving', 'VBG'),
#  ('copy', 'VB'),
#  ('was', 'VBD'),
#  ('chance', 'NN'),
#  ('check', 'VB'),
#  ('ps', 'NN'),
#  ('put', 'VBD'),
#  ('go', 'VB'),
#  ('ma', 'VBN'),
#  ('suggested', 'VBD'),
#  ('worst', 'JJS'),
#  ('na', 'JJ'),
#  ('clocks', 'NNS'),
#  ('feel', 'NN'),
#  ('sign', 'NN'),
#  ('365daysofgratefulness', 'CD'),
#  ('depreciate', 'VB'),
#  ('thankyou', 'RB'),
#  ('fucking', 'VBG'),
#  ('thanksfornothing', 'VBG'),
#  ('causes', 'NNS'),
#  ('sell', 'VB'),
#  ('profitering', 'VBG'),
#  ('going', 'VBG'),
#  ('am', 'VBP'),
#  ('disappointing', 'JJ'),
#  ('bandwidth', 'NN'),
#  ('kind', 'NN'),
#  ('enabled', 'VBN'),
#  ('sent', 'VBN'),
#  ('t', 'NN'),
#  ('coworker', 'NN'),
#  ('ty', 'VBP'),
#  ('original', 'JJ'),
#  ('utterly', 'RB'),
#  ('into', 'IN'),
#  ('miss', 'VBP'),
#  ('kong', 'NN'),
#  ('zero', 'CD'),
#  ('resolve', 'VB'),
#  ('models', 'NNS'),
#  ('immobile', 'NN'),
#  ('figures', 'NNS'),
#  ('neednewipadguide', 'VBP'),
#  ('durable', 'JJ'),
#  ('rcve', 'JJ'),
#  ('dreams', 'NNS'),
#  ('proper', 'IN'),
#  ('not', 'RB'),
#  ('wait', 'NN'),
#  ('gatos', 'NNS'),
#  ('learned', 'VBD'),
#  ('return', 'NN'),
#  ('but', 'CC'),
#  ('aside', 'RB'),
#  ('states', 'NNS'),
#  ('surviving', 'VBG'),
#  ('experience', 'VB'),
#  ('space', 'NN'),
#  ('make', 'VB'),
#  ('old', 'JJ'),
#  ('per', 'IN'),
#  ('ask', 'VB'),
#  ('in', 'IN'),
#  ('play', 'VBP'),
#  ('ya', 'NN'),
#  ('mandarin', 'NN'),
#  ('suspecting', 'VBG'),
#  ('yellowgate', 'VB'),
#  ('dear', 'VBP'),
#  ('look', 'VB'),
#  ('nothing', 'NN'),
#  ('come', 'VBP'),
#  ('os', 'NN'),
#  ('ipad1', 'NN'),
#  ('whatchu', 'VBZ'),
#  ('yeah', 'RB'),
#  ('impressive', 'JJ'),
#  ('chrome', 'NN'),
#  ('hold', 'NN'),
#  ('use', 'VBP'),
#  ('help', 'NN'),
#  ('argument', 'NN'),
#  ('i4s', 'NN'),
#  ('could', 'MD'),
#  ('offering', 'VBG'),
#  ('honest', 'NN'),
#  ('burn', 'VB'),
#  ('blessed', 'JJ'),
#  ('save', 'VB'),
#  ('siri', 'NNS'),
#  ('so', 'IN'),
#  ('add', 'VB'),
#  ('die', 'VBP'),
#  ('authorization', 'NN'),
#  ('location', 'NN'),
#  ('include', 'VBP'),
#  ('proper', 'JJ'),
#  ('siri', 'VBP'),
#  ('hasn', 'NN'),
#  ('repair', 'VB'),
#  ('password', 'NN'),
#  ('used', 'VBN'),
#  ('199', 'CD'),
#  ('4g', 'CD'),
#  ('nicki', 'NN'),
#  ('quality', 'NN'),
#  ('never', 'RB'),
#  ('correction', 'NN'),
#  ('model', 'NN'),
#  ('ma', 'NN'),
#  ('alamo', 'JJ'),
#  ('refurbished', 'JJ'),
#  ('authorise', 'NN'),
#  ('option', 'NN'),
#  ('gon', 'NN'),
#  ('impressed', 'VBD'),
#  ('upgrade', 'VBD'),
#  ('gets', 'VBZ'),
#  ('starts', 'VBZ'),
#  ('lacks', 'NNS'),
#  ('rip', 'NN'),
#  ('sooo', 'JJ'),
#  ('wan', 'NN'),
#  ('ah', 'NN'),
#  ('processor', 'NN'),
#  ('forget', 'VB'),
#  ('owner', 'NN'),
#  ('3hr', 'CD'),
#  ('body', 'NN'),
#  ('cleaned', 'VBN'),
#  ('soon', 'RB'),
#  ('to', 'TO'),
#  ('mobile', 'JJ'),
#  ('line', 'NN'),
#  ('function', 'NN'),
#  ('b', 'JJ'),
#  ('sweet', 'JJ'),
#  ('couldn', 'VBP'),
#  ('region', 'NN'),
#  ('iphone4', 'VB'),
#  ('terrible', 'JJ'),
#  ('photo', 'NN'),
#  ('doesn', 'VBZ'),
#  ('readinglists', 'NNS'),
#  ('remind', 'VBP'),
#  ('h', 'VB'),
#  ('ears', 'NNS'),
#  ('club', 'NN'),
#  ('mobileme', 'NN'),
#  ('mall', 'NN'),
#  ('submitted', 'VBN'),
#  ('without', 'IN'),
#  ('mb', 'NN'),
#  ('jackasses', 'NNS'),
#  ('custserv', 'NN'),
#  ('ibooks', 'NNS'),
#  ('wow', 'VBZ'),
#  ('dont', 'VBP'),
#  ('right', 'NN'),
#  ('able', 'JJ'),
#  ('conditions', 'NNS'),
#  ('care', 'NN'),
#  ('theft', 'NN'),
#  ('replacement', 'NN'),
#  ('confused', 'VBN'),
#  ('mommy', 'NN'),
#  ('dear', 'JJ'),
#  ('slows', 'VBZ'),
#  ('machine', 'NN'),
#  ('multiple', 'JJ'),
#  ('migrating', 'VBG'),
#  ('hotel', 'NN'),
#  ('publicly', 'RB'),
#  ('insurance', 'NN'),
#  ('4pm', 'CD'),
#  ('that', 'WDT'),
#  ('something', 'NN'),
#  ('pissing', 'VBG'),
#  ('brightness', 'JJ'),
#  ('exhibit', 'VBP'),
#  ('stink', 'VBP'),
#  ('andshuttingdownru', 'NN'),
#  ('shows', 'NNS'),
#  ('pop', 'NN'),
#  ('regent', 'JJ'),
#  ('last', 'JJ'),
#  ('30', 'CD'),
#  ('ios', 'RB'),
#  ('crazy', 'JJ'),
#  ('due', 'JJ'),
#  ('since', 'IN'),
#  ('3500', 'CD'),
#  ('copy', 'NN'),
#  ('shoot', 'VB'),
#  ('when', 'WRB'),
#  ('lk', 'VBD'),
#  ('searching', 'VBG'),
#  ('over', 'RP'),
#  ('means', 'VBZ'),
#  ('story', 'NN'),
#  ('started', 'VBD'),
#  ('month', 'NN'),
#  ('fatfuckingchance', 'NN'),
#  ('excited', 'VBN'),
#  ('it', 'PRP'),
#  ('reminders', 'NNS'),
#  ('continuously', 'RB'),
#  ('system', 'NN'),
#  ('warm', 'JJ'),
#  ('battery', 'NN'),
#  ('let', 'VB'),
#  ('teamed', 'VBN'),
#  ('earbuds', 'NNS'),
#  ('switch', 'VB'),
#  ('knew', 'VBD'),
#  ('s', 'VBD'),
#  ('service', 'NN'),
#  ('oh', 'RB'),
#  ('sorry', 'NN'),
#  ('absolutely', 'RB'),
#  ('pm', 'NN'),
#  ('ios5', 'VBP'),
#  ('coach', 'NN'),
#  ('second', 'NN'),
#  ('crankywithnophone', 'NN'),
#  ('off', 'IN'),
#  ('checkboxes', 'NNS'),
#  ('featured', 'JJ'),
#  ('hard', 'JJ'),
#  ('sign', 'VB'),
#  ('ios', 'NN'),
#  ('evil', 'JJ'),
#  ('intensifies', 'NNS'),
#  ('though', 'IN'),
#  ('takes', 'VBZ'),
#  ('had', 'VBN'),
#  ('keeps', 'NNS'),
#  ('turn', 'NN'),
#  ('saved', 'VBD'),
#  ('wit', 'NN'),
#  ('macbook', 'JJ'),
#  ('w', 'VBZ'),
#  ('if', 'IN'),
#  ('disappointment', 'NN'),
#  ('does', 'VBZ'),
#  ('endless', 'JJ'),
#  ('rt', 'VBZ'),
#  ('take', 'VB'),
#  ('podcast', 'NN'),
#  ('biz', 'NN'),
#  ('ate', 'NN'),
#  ('need', 'VBP'),
#  ('night', 'NN'),
#  ('ipads', 'NNS'),
#  ('data', 'NNS'),
#  ('have', 'VBP'),
#  ('dst', 'NN'),
#  ('mac', 'NN'),
#  ('messages', 'VBZ'),
#  ('didn', 'VBD'),
#  ('rva', 'NN'),
#  ('audio', 'JJ'),
#  ('employee', 'NN'),
#  ('hear', 'VB'),
#  ('paid', 'VBD'),
#  ('disappointing', 'VBG'),
#  ('worth', 'IN'),
#  ('windows', 'NNS'),
#  ('printed', 'VBD'),
#  ('stupid', 'JJ'),
#  ('die', 'VB'),
#  ('how', 'WRB'),
#  ('duplicates', 'NNS'),
#  ('user', 'NN'),
#  ('crashing', 'VBG'),
#  ('shhhh', 'VBD'),
#  ('talking', 'VBG'),
#  ('laundering', 'VBG'),
#  ('they', 'PRP'),
#  ('force', 'VB'),
#  ('25', 'CD'),
#  ('half', 'PDT'),
#  ('tossing', 'VBG'),
#  ('told', 'VBN'),
#  ('paid', 'VBN'),
#  ('airdrop', 'NN'),
#  ('ganna', 'JJ'),
#  ('future', 'NN'),
#  ('sadmac', 'NN'),
#  ('etc', 'FW'),
#  ('disappointed', 'JJ'),
#  ('there', 'EX'),
#  ('down', 'IN'),
#  ('sucking', 'VBG'),
#  ('bastards', 'NNS'),
#  ('question', 'NN'),
#  ('fucking', 'JJ'),
#  ('fuzzball', 'JJ'),
#  ('cable', 'NN'),
#  ('major', 'JJ'),
#  ('purchase', 'VB'),
#  ('lol', 'VB'),
#  ('none', 'NN'),
#  ('missed', 'VBN'),
#  ('outside', 'RB'),
#  ('inferno', 'NN'),
#  ('included', 'VBN'),
#  ('alive', 'JJ'),
#  ('should', 'MD'),
#  ('killed', 'VBD'),
#  ('w', 'JJ'),
#  ('hurts', 'VBZ'),
#  ('slowly', 'RB'),
#  ('45', 'CD'),
#  ('welcome', 'JJ'),
#  ('bring', 'NN'),
#  ('died', 'VBD'),
#  ('signal', 'JJ'),
#  ('hello', 'NN'),
#  ('cracked', 'VBD'),
#  ('disruptions', 'NNS'),
#  ('four', 'CD'),
#  ('fixed', 'VBD'),
#  ('app', 'JJ'),
#  ('about', 'IN'),
#  ('game', 'NN'),
#  ('run', 'VB'),
#  ('buy', 'VB'),
#  ('cost', 'NN'),
#  ('mine', 'NN'),
#  ('blaring', 'NN'),
#  ('tragic', 'JJ'),
#  ('pick', 'VB'),
#  ('lives', 'NNS'),
#  ('b4', 'NN'),
#  ('amazing', 'VBG'),
#  ('innovations', 'NNS'),
#  ('cracked', 'VBN'),
#  ('braille', 'NN'),
#  ('suck', 'VB'),
#  ('please', 'VBZ'),
#  ('trip', 'NN'),
#  ('previous', 'JJ'),
#  ('flawless', 'JJ'),
#  ('website', 'NN'),
#  ('surely', 'RB'),
#  ('integrated', 'JJ'),
#  ('t', 'VBP'),
#  ('only', 'JJ'),
#  ('girlies', 'NNS'),
#  ('indian', 'JJ'),
#  ('feeding', 'NN'),
#  ('pls', 'NN'),
#  ('spoke', 'NN'),
#  ('319', 'CD'),
#  ('mack', 'NN'),
#  ('problems', 'NNS'),
#  ('please', 'JJ'),
#  ('s', 'RB'),
#  ('car', 'NN'),
#  ('change', 'VB'),
#  ('lost', 'VBD'),
#  ('years', 'NNS'),
#  ('notcool', 'NN'),
#  ('closing', 'VBG'),
#  ('slow', 'JJ'),
#  ('props', 'NNS'),
#  ('fantasy', 'NN'),
#  ('doesnt', 'JJ'),
#  ('isn', 'VBZ'),
#  ('issues', 'NNS'),
#  ('sloppy', 'JJ'),
#  ('many', 'JJ'),
#  ('water', 'NN'),
#  ('removing', 'VBG'),
#  ('ringing', 'VBG'),
#  ('iphone', 'CD'),
#  ('fuck', 'NN'),
#  ('stuck', 'VBN'),
#  ('slide', 'NN'),
#  ('merchandising', 'NN'),
#  ('clue', 'NN'),
#  ('serves', 'VBZ'),
#  ('worse', 'JJR'),
#  ('AT_TOKEN', 'VB'),
#  ('2001', 'CD'),
#  ('right', 'JJ'),
#  ('open', 'JJ'),
#  ('screw', 'NN'),
#  ('iphone2', 'JJ'),
#  ('another', 'DT'),
#  ('sorry', 'VBP'),
#  ('garden', 'NN'),
#  ('pc', 'VBP'),
#  ('replace', 'VB'),
#  ('awesome', 'JJ'),
#  ('tech', 'JJ'),
#  ('step', 'NN'),
#  ('princessofchina', 'NNS'),
#  ('opposite', 'NN'),
#  ('update', 'VB'),
#  ('strangest', 'JJS'),
#  ('buttery', 'NN'),
#  ('test', 'VB'),
#  ('clarence', 'NN'),
#  ('harder', 'VBP'),
#  ('give', 'VB'),
#  ('credit', 'NN'),
#  ('23', 'CD'),
#  ('macworld', 'VBP'),
#  ('keys', 'NNS'),
#  ('beyond', 'IN'),
#  ('purchase', 'NN'),
#  ('purchased', 'JJ'),
#  ('ailing', 'VBG'),
#  ('best', 'JJS'),
#  ('i', 'VB'),
#  ('quickly', 'RB'),
#  ('auto', 'NN'),
#  ('computer', 'NN'),
#  ('curse', 'VB'),
#  ('getting', 'VBG'),
#  ('i', 'NNS'),
#  ('ppl', 'VBZ'),
#  ('over', 'IN'),
#  ('bro', 'VBZ'),
#  ('goodriddance', 'NN'),
#  ('ha', 'VB'),
#  ('cool', 'VBP'),
#  ('consolidation', 'NN'),
#  ('0', 'CD'),
#  ('refurbed', 'NN'),
#  ('what', 'WP'),
#  ('sms', 'JJ'),
#  ('perhaps', 'RB'),
#  ('t', 'JJ'),
#  ('replacing', 'VBG'),
#  ('crap', 'VBZ'),
#  ('connection', 'NN'),
#  ('the', 'DT'),
#  ('shit', 'VB'),
#  ('efffing', 'VBG'),
#  ('spaces', 'NNS'),
#  ('stand', 'VBP'),
#  ('you', 'PRP'),
#  ('spending', 'NN'),
#  ('sending', 'VBG'),
#  ('figure', 'VB'),
#  ('yellow', 'JJ'),
#  ('often', 'RB'),
#  ('carrier', 'NN'),
#  ('crashes', 'VBZ'),
#  ('2', 'CD'),
#  ('ios5downgrade', 'NN'),
#  ('truly', 'NN'),
#  ('ps', 'IN'),
#  ('sought', 'VBN'),
#  ('text', 'VB'),
#  ('pro', 'JJ'),
#  ('between', 'IN'),
#  ('cardsapp', 'NN'),
#  ('damage', 'NN'),
#  ('ve', 'NNS'),
#  ('inspire', 'VBP'),
#  ('seen', 'VBN'),
#  ('ipod4s', 'NN'),
#  ('days', 'NNS'),
#  ('turn', 'VB'),
#  ('24', 'CD'),
#  ('bump', 'NN'),
#  ('electric', 'JJ'),
#  ('restore', 'VB'),
#  ('around', 'RB'),
#  ('sigh', 'JJ'),
#  ('contacts', 'VBZ'),
#  ('cancer', 'NN'),
#  ('sms', 'NNS'),
#  ('wit', 'JJ'),
#  ('note', 'NN'),
#  ('slower', 'JJR'),
#  ('suburbs', 'NNS'),
#  ('ripstevejobs', 'NN'),
#  ('affair', 'NN'),
#  ('warning', 'NN'),
#  ('direct', 'JJ'),
#  ('butler', 'NN'),
#  ('servers', 'NNS'),
#  ('remember', 'VB'),
#  ('droid', 'NN'),
#  ('wow', 'VBP'),
#  ('pretty', 'NNS'),
#  ('powered', 'VBD'),
#  ('via', 'IN'),
#  ('send', 'VBP'),
#  ('nexus', 'CC'),
#  ('wont', 'VBZ'),
#  ('annoyed', 'VB'),
#  ('yapping', 'VBG'),
#  ('terminal', 'JJ'),
#  ('making', 'VBG'),
#  ('she', 'PRP'),
#  ('gb', 'NN'),
#  ('upgrades', 'NNS'),
#  ('triple', 'NN'),
#  ('obviously', 'RB'),
#  ('appleupdates2', 'NN'),
#  ('hope', 'VB'),
#  ('down', 'RP'),
#  ('disaster', 'NN'),
#  ('spoiled', 'VBN'),
#  ('ugh', 'IN'),
#  ('bahhh', 'FW'),
#  ('canada', 'JJ'),
#  ('hockey', 'JJ'),
#  ('more', 'RBR'),
#  ('spend', 'JJ'),
#  ('briliant', 'NN'),
#  ('fruits', 'NNS'),
#  ('uch', 'JJ'),
#  ('class', 'NN'),
#  ('40', 'CD'),
#  ('downloaded', 'VBN'),
#  ('light', 'VBD'),
#  ('ganna', 'NN'),
#  ('osx', 'JJ'),
#  ('check', 'NN'),
#  ('deleted', 'VBN'),
#  ('walk', 'NN'),
#  ('wow', 'IN'),
#  ('signups', 'VBP'),
#  ('screen', 'VB'),
#  ('songs', 'NNS'),
#  ('sync', 'NN'),
#  ('error', 'NN'),
#  ('damn', 'NN'),
#  ('match', 'NN'),
#  ('lies', 'VBZ'),
#  ('bad', 'JJ'),
#  ('who', 'WP'),
#  ('says', 'VBZ'),
#  ('utter', 'NN'),
#  ('reminder', 'NN'),
#  ('anyone', 'NN'),
#  ('may', 'MD'),
#  ('above', 'IN'),
#  ('d', 'VBP'),
#  ('worst', 'RB'),
#  ('twitter', 'NN'),
#  ('owns', 'VBZ'),
#  ('authorize', 'NN'),
#  ('intuitive', 'JJ'),
#  ('installing', 'VBG'),
#  ('certain', 'JJ'),
#  ('such', 'JJ'),
#  ('syncs', 'NN'),
#  ('hope', 'VBP'),
#  ('while', 'NN'),
#  ('yeah', 'NN'),
#  ('sunday', 'NN'),
#  ('w', 'VB'),
#  ('gods', 'NNS'),
#  ('recognition', 'NN'),
#  ('blue', 'NN'),
#  ('expected', 'VBN'),
#  ('fail', 'VB'),
#  ('cute', 'NN'),
#  ('fucks', 'NNS'),
#  ('m', 'NNS'),
#  ('paying', 'VBG'),
#  ('star', 'JJ'),
#  ('brightness', 'NN'),
#  ('located', 'VBN'),
#  ('facetime', 'JJ'),
#  ('recovered', 'VBN'),
#  ('equal', 'JJ'),
#  ('outlook', 'NN'),
#  ('connect', 'VB'),
#  ('closed', 'VBN'),
#  ('try', 'VBP'),
#  ('video', 'NN'),
#  ('rep', 'NN'),
#  ('ipod', 'NN'),
#  ('them', 'PRP'),
#  ('present', 'NN'),
#  ('mail', 'NN'),
#  ('team', 'NN'),
#  ('moment', 'NN'),
#  ('notifies', 'NNS'),
#  ('think', 'VBP'),
#  ('light', 'JJ'),
#  ('76', 'CD'),
#  ('listening', 'VBG'),
#  ('leopard', 'RB'),
#  ('t', 'RB'),
#  ('techy', 'JJ'),
#  ('thankful', 'NN'),
#  ('loop', 'JJ'),
#  ('clicking', 'VBG'),
#  ('millions', 'NNS'),
#  ('say', 'VBP'),
#  ('sprint', 'VBP'),
#  ('incredible', 'JJ'),
#  ('no', 'RB'),
#  ('fix', 'NN'),
#  ('ios5', 'VBN'),
#  ('get', 'VBP'),
#  ('giving', 'VBG'),
#  ('sister', 'NN'),
#  ('ur', 'JJ'),
#  ('tones', 'NNS'),
#  ('event', 'NN'),
#  ('wack', 'JJ'),
#  ('studying', 'VBG'),
#  ('12', 'CD'),
#  ('back', 'RB'),
#  ('ideas', 'NNS'),
#  ('like', 'VB'),
#  ('wife', 'NN'),
#  ('r', 'NN'),
#  ('integrate', 'VB'),
#  ('hiss', 'NN'),
#  ('htc', 'NN'),
#  ('lolol', 'NN'),
#  ('amount', 'NN'),
#  ('lt', 'VBP'),
#  ('txts', 'NNS'),
#  ('network', 'NN'),
#  ('nor', 'CC'),
#  ('podcasts', 'NNS'),
#  ('much', 'RB'),
#  ('problem', 'NN'),
#  ('hero', 'NN'),
#  ('wan', 'WP'),
#  ('inbox', 'NN'),
#  ('read', 'JJ'),
#  ('continuing', 'VBG'),
#  ('ve', 'VBD'),
#  ('youuuuuuuuuuuu', 'JJ'),
#  ('failing', 'VBG'),
#  ('finance', 'NN'),
#  ('finest', 'JJS'),
#  ('folks', 'NNS'),
#  ('australiapatent', 'JJ'),
#  ('and', 'CC'),
#  ('nonstop', 'NN'),
#  ('wristpad', 'NN'),
#  ('upgrade', 'NN'),
#  ('tone', 'NN'),
#  ('upload', 'NN'),
#  ('trying', 'VBG'),
#  ('sounds', 'NNS'),
#  ('in2', 'JJ'),
#  ('iosdonwgrade', 'NN'),
#  ('forward', 'RB'),
#  ('purchasing', 'VBG'),
#  ('resources', 'NNS'),
#  ('dilation', 'NN'),
#  ('too', 'RB'),
#  ('can', 'MD'),
#  ('m', 'RB'),
#  ('ordered', 'VBD'),
#  ('lmao', 'NN'),
#  ('appointment', 'NN'),
#  ('sith', 'NN'),
#  ('staff', 'NN'),
#  ('preorder', 'NN'),
#  ('i', 'VBP'),
#  ('shit', 'VBD'),
#  ('address', 'NN'),
#  ('inept', 'JJ'),
#  ('skin', 'NN'),
#  ('drain', 'NN'),
#  ('rock', 'NN'),
#  ('tonite', 'RB'),
#  ('download', 'NN'),
#  ('touch', 'NN'),
#  ('i', 'NN'),
#  ('each', 'DT'),
#  ('4s', 'CD'),
#  ('f', 'JJ'),
#  ('education', 'NN'),
#  ('importance', 'NN'),
#  ('points', 'NNS'),
#  ('lose', 'VB'),
#  ('shit', 'VBN'),
#  ('y', 'NN'),
#  ('eye', 'NN'),
#  ('phone', 'NN'),
#  ('handy', 'JJ'),
#  ('tiger', 'NN'),
#  ('these', 'DT'),
#  ('honored', 'VBN'),
#  ('bellevue', 'NN'),
#  ('year', 'NN'),
#  ('rt', 'NN'),
#  ('french', 'JJ'),
#  ('media', 'NNS'),
#  ('online', 'NN'),
#  ('arrived', 'VBN'),
#  ('icloud', 'VB'),
#  ('o', 'NN'),
#  ('late', 'RB'),
#  ('isn', 'VB'),
#  ('have', 'VB'),
#  ('having', 'VBG'),
#  ('cause', 'VBP'),
#  ('one', 'NN'),
#  ('magic', 'JJ'),
#  ('folder', 'NN'),
#  ('thursday', 'NN'),
#  ('gigs', 'NNS'),
#  ('toledooh', 'RB'),
#  ('believe', 'VB'),
#  ('iphone4s', 'VB'),
#  ('berry', 'NN'),
#  ('goes', 'VBZ'),
#  ('100', 'CD'),
#  ('type', 'NN'),
#  ('alert', 'NN'),
#  ('simplifies', 'VBZ'),
#  ('hold', 'VB'),
#  ('welcome', 'NN'),
#  ('700', 'CD'),
#  ('apple', 'NN'),
#  ('person', 'NN'),
#  ('lmfao', 'JJ'),
#  ('didn', 'VBZ'),
#  ('app', 'NN'),
#  ('iphone4s', 'JJ'),
#  ('handle', 'VB'),
#  ('things', 'NNS'),
#  ('ta', 'RB'),
#  ('yourdaysarenumbered', 'VBD'),
#  ('tonight', 'NN'),
#  ('snow', 'VBP'),
#  ('from', 'IN'),
#  ('know', 'VBP'),
#  ('wth', 'NN'),
#  ('request', 'NN'),
#  ('puck', 'NN'),
#  ('w', 'VBP'),
#  ('send', 'VB'),
#  ('failed', 'VBD'),
#  ('using', 'VBG'),
#  ('shows', 'VBZ'),
#  ('screwing', 'VBG'),
#  ('cheer', 'VB'),
#  ('operating', 'VBG'),
#  ('unexpected', 'JJ'),
#  ('architecture', 'NN'),
#  ('complaints', 'NNS'),
#  ('screen', 'JJ'),
#  ('10', 'CD'),
#  ('already', 'RB'),
#  ('whores', 'NNS'),
#  ('photos', 'NNS'),
#  ('excited', 'JJ'),
#  ('crack', 'NN'),
#  ('25mb', 'CD'),
#  ('hindi', 'NN'),
#  ('gm', 'NN'),
#  ('japan', 'NN'),
#  ('suckers', 'NNS'),
#  ('cloud', 'NN'),
#  ('jolly', 'RB'),
#  ('our', 'PRP$'),
#  ('continued', 'VBD'),
#  ('think', 'VB'),
#  ('someone', 'NN'),
#  ('3x', 'CD'),
#  ('commands', 'NNS'),
#  ('simple', 'NN'),
#  ('forces', 'VBZ'),
#  ('hdv', 'JJ'),
#  ('t', 'VBZ'),
#  ('delivered', 'VBN'),
#  ('put', 'VB'),
#  ('served', 'VBN'),
#  ('crappy', 'JJ'),
#  ('hand', 'NN'),
#  ('4ss', 'CD'),
#  ('glad', 'JJ'),
#  ('s', 'VB'),
#  ('former', 'JJ'),
#  ('silly', 'RB'),
#  ('9', 'CD'),
#  ('schedule', 'NN'),
#  ('youre', 'NN'),
#  ('needsomethingtoread', 'NN'),
#  ('shit', 'NN'),
#  ('poor', 'JJ'),
#  ('release', 'VBP'),
#  ('install', 'JJ'),
#  ('pdfs', 'NN'),
#  ('do', 'VBP'),
#  ('hp', 'NN'),
#  ('thats', 'NNS'),
#  ('once', 'RB'),
#  ('click', 'NN'),
#  ('worked', 'VBN'),
#  ('thankfully', 'RB'),
#  ('trouble', 'NN'),
#  ('back', 'JJ'),
#  ('notifications', 'NNS'),
#  ('product', 'NN'),
#  ('dependent', 'JJ'),
#  ('hopefully', 'RB'),
#  ('looks', 'VBZ'),
#  ('internet', 'NN'),
#  ('local', 'JJ'),
#  ('with', 'IN'),
#  ('comp', 'NN'),
#  ('petty', 'NN'),
#  ('rest', 'NN'),
#  ('process', 'VB'),
#  ('thorough', 'JJ'),
#  ('plan', 'NN'),
#  ('santa', 'VB'),
#  ('power', 'NN'),
#  ('control', 'NN'),
#  ('nice', 'JJ'),
#  ('storage', 'NN'),
#  ('fade', 'VBP'),
#  ('reader', 'NN'),
#  ('couldn', 'NN'),
#  ('re', 'VB'),
#  ('reservation', 'NN'),
#  ('orging', 'VBG'),
#  ('we', 'PRP'),
#  ('hell', 'NN'),
#  ('seemingly', 'RB'),
#  ('minutes', 'NNS'),
#  ('tells', 'VBZ'),
#  ('reaching', 'VBG'),
#  ('preordered', 'VBD'),
#  ('domain', 'NN'),
#  ('need4s', 'NN'),
#  ('houston', 'NN'),
#  ('do', 'VB'),
#  ('managed', 'VBD'),
#  ('yo', 'RB'),
#  ('company', 'NN'),
#  ('inconvenienced', 'VBN'),
#  ('stores', 'NNS'),
#  ('im', 'NN'),
#  ('before', 'IN'),
#  ('lol', 'NN'),
#  ('immediate', 'NN'),
#  ('itouch', 'JJ'),
#  ('late', 'JJ'),
#  ('showing', 'VBG'),
#  ('parents', 'NNS'),
#  ('tried', 'VBD'),
#  ('nuts', 'JJ'),
#  ('desktop', 'NN'),
#  ('prctices', 'NNS'),
#  ('apperature', 'NN'),
#  ('one', 'CD'),
#  ('quite', 'RB'),
#  ('second', 'JJ'),
#  ('apps', 'NNS'),
#  ('morning', 'NN'),
#  ('alarms', 'NNS'),
#  ('mention', 'NN'),
#  ('pulls', 'VBZ'),
#  ('syncing', 'VBG'),
#  ('blames', 'NNS'),
#  ('artist', 'NN'),
#  ('ical', 'JJ'),
#  ('extend', 'VBP'),
#  ('are', 'VBP'),
#  ('invention', 'NN'),
#  ('creative', 'JJ'),
#  ('hoping', 'VBG'),
#  ('ny', 'JJ'),
#  ('90', 'CD'),
#  ('deals', 'NNS'),
#  ('randomly', 'RB'),
#  ('um', 'JJ'),
#  ('stop', 'NN'),
#  ('upgrading', 'VBG'),
#  ('lasted', 'VBD'),
#  ('own', 'VB'),
#  ('mentor', 'NN'),
#  ('wuhu', 'NN'),
#  ('interrupting', 'NN'),
#  ('replaceit', 'NN'),
#  ('while', 'IN'),
#  ('least', 'JJS'),
#  ...]

# %% [markdown]
# ### Creating the feature vector
# The feature vector that is to be created is in the following format:e.g.
# <blockquote>{'simplistic': False, 'silly': True, 'and': True, 'tedious': False, 'its': False, 'so': True, 'laddish': False, 'juvenile': False, 'only': False, 'teenage': False, 'boys': False, 'could': False, 'possibly': False, 'find': False, 'it': False, 'funny': False, 'exploitative': False, 'largely': False, 'devoid': False}</blockquote><br>
# Instructions on how to make the feature vectors:
# <ul>
#     <li><b>For each tweet</b> the feature vector to be constructed will be equal to the <b>size of the vocabulary</b>.</li>
#     <li>The feature vector is a dictionary with <b>word and boolean pairs</b>, here the boolean will be <b>true</b> if the specific word exists in the tweet otherwise it will be <b>false</b>.</li>
#
# </ul>

# %%
def features_unigram(data,vocab):
    """
    Returns list of feature vectors

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique unigrams
    """
    newList = []
    for i in range(len(data)):
        newDict = {}
        for value in vocab:
            newDict[value]= False
        newList.append(newDict)
    j = 0
    for val in data['text']:
        #print(val)
        for subval in val:
            if subval in vocab:
                newList[j][subval] = True
        j=j+1
    return newList
def features_bigram(data,vocab):
    """
    Returns list of unique bigrams

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique bigrams
    """
    newList = []
    for i in range(len(data)):
        newDict = {}
        for value in vocab:
            newDict[value] = False
        newList.append(newDict)
    j = 0
    for val in data['text']:
        for subval in val:
            if subval in vocab:
                newList[j][subval] = True
        j = j+1
    return newList
def features_POS(data,vocab):
    """
    Returns list of unique POS tags

    Args:
        data : list of tweets
    
    Returns: vocab_unigram: list of unique POS tags
    """
    newList = []
    for i in range(len(data)):
        newDict = {}
        for value in vocab:
            newDict[value] = False
        newList.append(newDict)
    j = 0
    for val in data['text']:
        for subval in val:
            if subval in vocab:
                newList[j][subval] = True
        j = j+1
    return newList
task1_unigram_features=features_unigram(tweet_X_task1,vocab_unigram_task1)
task1_bigram_features=features_bigram(tweet_X_task1,vocab_bigram_task1)
task1_POS_features=features_POS(tweet_X_task1,vocab_pos_tag_task1)

task2_unigram_features=features_unigram(tweet_X_task2,vocab_unigram_task2)
task2_bigram_features=features_bigram(tweet_X_task2,vocab_bigram_task2)
task2_POS_features=features_POS(tweet_X_task2,vocab_pos_tag_task2)

# %%
task1_unigram_features[1]
# Out:
# {'health': False,
#  'overall': False,
#  'bottom': False,
#  'apparently': False,
#  'voice': False,
#  'this': False,
#  'carrier': True,
#  'throws': False,
#  'impressed': False,
#  'cutting': False,
#  'invention': False,
#  'p': False,
#  'hear': False,
#  'probono': False,
#  'apt': False,
#  'ours': False,
#  'in2': False,
#  'best': False,
#  '69': False,
#  'glass': False,
#  'there': False,
#  'mo': False,
#  'were': False,
#  'inbox': False,
#  'will': True,
#  'lot': False,
#  'regent': False,
#  'last': False,
#  'galaxy': False,
#  'covers': False,
#  'sucking': False,
#  'using': False,
#  'who': False,
#  'owns': False,
#  'loose': False,
#  'snippy': False,
#  'empty': False,
#  'policies': False,
#  'preventing': False,
#  'worse': False,
#  'almost': False,
#  'loss': False,
#  '700': False,
#  'harder': False,
#  'thorough': False,
#  'wth': False,
#  'did': False,
#  'plate': False,
#  'sounds': False,
#  'fb': False,
#  'card': False,
#  'japan': False,
#  'so': False,
#  'order': False,
#  'now': False,
#  'located': False,
#  'cool': False,
#  'eggs': False,
#  'magically': False,
#  'listening': False,
#  'hong': False,
#  'sith': False,
#  'occur': False,
#  'play': False,
#  'lack': False,
#  'need': False,
#  'terrible': False,
#  'wants': False,
#  'lead': False,
#  'way': False,
#  'newstand': False,
#  'garden': False,
#  'simple': False,
#  'service': False,
#  'wristpad': False,
#  'upgrade': False,
#  'experience': False,
#  'readinglists': False,
#  'an': False,
#  'reported': False,
#  'cloud': False,
#  'product': False,
#  'putting': False,
#  'retail': False,
#  'stylus': False,
#  'ps': False,
#  'smart': False,
#  'seeing': False,
#  '30': False,
#  'incapable': False,
#  'sigh': False,
#  'officially': False,
#  'swype': False,
#  'sucks': False,
#  'emptythreats': False,
#  'whaddupwitdat': False,
#  'dear': False,
#  'ppl': False,
#  'dreams': False,
#  'inept': False,
#  'served': False,
#  'lose': False,
#  'reboot': False,
#  'tonight': False,
#  'notbook': False,
#  'idk': False,
#  'thankyou': False,
#  'calling': False,
#  'died': False,
#  'distributing': False,
#  'training': False,
#  'terms': False,
#  'error': False,
#  'proving': False,
#  'h': False,
#  'yo': False,
#  'didn': False,
#  'type': False,
#  'tell': False,
#  'about': False,
#  'paid': False,
#  'painfully': False,
#  'working': False,
#  'sms': False,
#  'qa': False,
#  'replacing': False,
#  'they': False,
#  'da': False,
#  'pcam': False,
#  'screwed': False,
#  'offing': False,
#  'failed': False,
#  'enhance': False,
#  'figure': False,
#  'proper': False,
#  'butler': False,
#  'sprint': False,
#  'andshuttingdownrunningprograms': False,
#  'say': False,
#  'well': False,
#  'kind': False,
#  'investigate': False,
#  'spontaneously': False,
#  'spoiled': False,
#  'yessss': False,
#  'screwing': False,
#  '23': False,
#  'madness': False,
#  'uch': False,
#  'nam': False,
#  'playbooks': False,
#  'totally': False,
#  'w': False,
#  'buttery': False,
#  'needsomethingtoread': False,
#  '2012': False,
#  'hour': False,
#  'ram': False,
#  'andshuttingdownru': False,
#  'seemed': False,
#  'synching': False,
#  'updates': False,
#  'contact': False,
#  'do': False,
#  'r': False,
#  'name': False,
#  'plz': False,
#  'outlook': False,
#  'feel': False,
#  'issue': False,
#  'doesnt': False,
#  'someone': False,
#  'white': False,
#  'mobile': False,
#  'water': False,
#  'ma': False,
#  'bell': False,
#  'disappear': False,
#  'download': False,
#  '4g': False,
#  'focus': False,
#  'version': False,
#  'app': False,
#  'duped': False,
#  'lies': False,
#  'its': False,
#  'alamo': False,
#  'takes': False,
#  'air': False,
#  'removing': False,
#  'line': False,
#  'black': False,
#  'went': False,
#  'aaron': False,
#  'mentor': False,
#  'wuhu': False,
#  'interrupting': False,
#  'release': False,
#  'fuzzball': False,
#  'crashes': False,
#  '135': False,
#  'story': False,
#  'painful': False,
#  'worldwide': False,
#  'centre': False,
#  'sd': False,
#  'whatchu': False,
#  'site': False,
#  'non': False,
#  'popular': False,
#  'bg': False,
#  'installing': False,
#  'efffing': False,
#  'voicecontrol': False,
#  'setting': False,
#  'inform': False,
#  'folder': False,
#  'photo': False,
#  'sorry': False,
#  'just': True,
#  'itunesmatch': False,
#  'u': False,
#  'very': False,
#  'office': False,
#  'cell': False,
#  'txts': False,
#  'lacks': False,
#  'completely': False,
#  'thats': False,
#  'wife': False,
#  'briliant': False,
#  'remembering': False,
#  '7': False,
#  'apptment': False,
#  'asked': False,
#  'try': False,
#  'iosdonwgrade': False,
#  '9': False,
#  'dammit': False,
#  'meant': False,
#  'mute': False,
#  'evo': False,
#  'servers': False,
#  'option': False,
#  'everything': False,
#  'your': False,
#  'braille': False,
#  'open': False,
#  'st': False,
#  'being': False,
#  'far': False,
#  'one': False,
#  'mega': False,
#  'number': False,
#  'undo': False,
#  'closing': False,
#  'cardsapp': False,
#  'see': False,
#  '4pm': False,
#  'definitely': False,
#  'art': False,
#  'featured': False,
#  'disaster': False,
#  'wiped': False,
#  'pages': False,
#  '16': False,
#  'destroying': False,
#  'too': False,
#  'bummer': False,
#  'pls': False,
#  'i': False,
#  'itjustworks': False,
#  'launching': False,
#  'ie': False,
#  'worth': False,
#  'needs': False,
#  'annoyed': False,
#  'ipod4s': False,
#  'promised': False,
#  'idisk': False,
#  'bar': False,
#  'rt': False,
#  'points': False,
#  'delete': False,
#  'missing': False,
#  'home': False,
#  'however': False,
#  'suspecting': False,
#  'surprises': False,
#  'take': False,
#  'handled': False,
#  'write': False,
#  'direct': False,
#  '3hr': False,
#  'um': False,
#  'wont': False,
#  'hello': False,
#  'morning': False,
#  'complain': False,
#  'agree': False,
#  'checkboxes': False,
#  'stumped': False,
#  'pissed': False,
#  'sorude': False,
#  'education': False,
#  'side': False,
#  'help': False,
#  'argument': False,
#  'importance': False,
#  'rock': False,
#  'comparing': False,
#  'apologize': False,
#  'electric': False,
#  'it': False,
#  'turning': False,
#  'hoping': False,
#  'rcve': False,
#  'should': False,
#  'nor': False,
#  'makes': False,
#  'overcapacity': False,
#  'complaints': False,
#  'reminders': False,
#  'duff': False,
#  'street': False,
#  'mightily': False,
#  'that': False,
#  'amused': False,
#  'witchcraft': False,
#  'saved': False,
#  'eyelash': False,
#  'bullshit': False,
#  'compilation': False,
#  'suburbs': False,
#  'lame': False,
#  'model': False,
#  'think': False,
#  'force': False,
#  'studying': False,
#  'paying': False,
#  'booked': False,
#  'purchased': False,
#  'millenia': False,
#  'replaceit': False,
#  'ship': False,
#  'upgrades': False,
#  'haha': False,
#  'called': False,
#  'ordered': False,
#  'tossing': False,
#  'duet': False,
#  'canada': False,
#  'photos': False,
#  'workstation': False,
#  'updating': False,
#  'apply': False,
#  'exhibit': False,
#  'stink': False,
#  'admit': False,
#  'would': False,
#  'keeps': False,
#  'trouble': False,
#  'goes': False,
#  'hasn': False,
#  'warning': False,
#  'ios5downgrade': False,
#  'are': False,
#  'sorri': False,
#  'though': False,
#  'faster': False,
#  'read': False,
#  'really': False,
#  'combo': False,
#  'here': False,
#  'user': False,
#  'garbage': False,
#  'continuing': False,
#  'chaos': False,
#  'man': False,
#  'os': False,
#  'expensivepaperweight': False,
#  'survey': False,
#  'yourdaysarenumbered': False,
#  'bloomberg': False,
#  'geolocation': False,
#  'dead': False,
#  'smartphone': False,
#  'tried': False,
#  'dodgy': False,
#  'cap': False,
#  'avail': False,
#  'huh': False,
#  'baby': False,
#  'mention': False,
#  'restrictions': False,
#  'of': False,
#  'models': False,
#  'hiss': False,
#  'stewart': False,
#  'messages': False,
#  'custserv': False,
#  'people': False,
#  'useless': False,
#  'must': False,
#  'razr': False,
#  'resources': False,
#  'compatible': False,
#  'subscriptions': False,
#  'committed': False,
#  'teams': False,
#  'return': False,
#  'star': False,
#  'magical': False,
#  'info': False,
#  'trip': False,
#  'something': False,
#  'equipment': False,
#  'location': False,
#  'stand': False,
#  'looks': False,
#  'his': False,
#  'slipping': False,
#  'waaaaay': False,
#  'continued': False,
#  'right': False,
#  'rename': False,
#  'programs': False,
#  'pay': False,
#  'company': False,
#  'music': False,
#  'longer': False,
#  'thunderbird': False,
#  'local': False,
#  'meet': False,
#  'sports': False,
#  'apology': False,
#  'awsome': False,
#  'total': False,
#  'at': False,
#  '20': False,
#  'event': False,
#  'forces': False,
#  'nicki': False,
#  'registered': False,
#  'much': False,
#  'thievingbastards': False,
#  'phones': False,
#  'remind': False,
#  'within': False,
#  'laptop': False,
#  'my': False,
#  'architecture': False,
#  'document': False,
#  'offers': False,
#  'actually': False,
#  'replacement': False,
#  'original': False,
#  'red': False,
#  'answer': False,
#  'integrate': False,
#  'pro': False,
#  'finally': False,
#  'explain': False,
#  'pre': False,
#  'nohelp': False,
#  'hard': False,
#  'rice': False,
#  'neednewipadguide': False,
#  'protect': False,
#  'stable': False,
#  'eta': False,
#  'biltmore': False,
#  'hire': False,
#  'arrogant': False,
#  'kudos': False,
#  'standards': False,
#  'correction': False,
#  'dis': False,
#  'lisa': False,
#  'safari': False,
#  'brain': False,
#  'feeding': False,
#  'i4s': False,
#  'techietroubles': False,
#  'moving': False,
#  'ok': False,
#  'gods': False,
#  'appstore': False,
#  'equivalent': False,
#  'gets': False,
#  'starts': False,
#  'request': False,
#  'machine': False,
#  'impressions': False,
#  'gr': False,
#  'cuz': False,
#  '3x': False,
#  'knew': False,
#  'fail': False,
#  'represent': False,
#  'night': False,
#  'fuck': False,
#  'have': False,
#  'stuck': False,
#  'backside': False,
#  '0': False,
#  'cancer': False,
#  'keep': False,
#  'damage': False,
#  'save': False,
#  'iphoto': False,
#  'giving': False,
#  'dark': False,
#  'obnoxious': False,
#  'poor': False,
#  'expensive': False,
#  'vertical': False,
#  'bus': False,
#  'learned': False,
#  'crappy': False,
#  'she': False,
#  'ipads': False,
#  'iphones': False,
#  'blend': False,
#  'ideas': False,
#  'same': False,
#  'unhappy': False,
#  'thoughtful': False,
#  'horizontal': False,
#  'personal': False,
#  'syncronize': False,
#  'updater': False,
#  'reliable': False,
#  'spoke': False,
#  'fu': False,
#  'each': False,
#  'hold': False,
#  'b': False,
#  'instead': False,
#  'bound': False,
#  'plans': False,
#  'biz': False,
#  'piece': False,
#  'thomas': False,
#  'purpose': False,
#  'incompatible': False,
#  'terpstra': False,
#  'doing': False,
#  'unreal': False,
#  'awesome': False,
#  'make': False,
#  'her': False,
#  'mail': False,
#  'bc': False,
#  'beyond': False,
#  'rapidly': False,
#  'deleted': False,
#  'vegas': False,
#  '15': False,
#  'fuh': False,
#  'present': False,
#  'apple': False,
#  'worked': False,
#  'long': False,
#  'gave': False,
#  'which': False,
#  'first': False,
#  'sux': False,
#  'luck': False,
#  'crashing': False,
#  'smartest': False,
#  '76': False,
#  'noreply': False,
#  'where': False,
#  'server': False,
#  'apperature': False,
#  'keyboard': False,
#  'wireless': False,
#  'io5': False,
#  'insurance': False,
#  'except': False,
#  'preordered': False,
#  'lock': False,
#  'charging': False,
#  'share': False,
#  'recover': False,
#  'flash': False,
#  'merchandising': False,
#  'also': False,
#  'tone': False,
#  'upload': False,
#  'walled': False,
#  'jailbroken': False,
#  'until': False,
#  'consolidation': False,
#  'flawless': False,
#  'laid': False,
#  'bought': False,
#  'compact': False,
#  'drain': False,
#  'album': False,
#  'talking': False,
#  '1': False,
#  'little': False,
#  '24': False,
#  'decide': False,
#  'freezes': False,
#  'lords': False,
#  't': False,
#  'leopard': False,
#  'coworker': False,
#  'bode': False,
#  'vibrate': False,
#  'perfectly': False,
#  'grass': False,
#  'especially': False,
#  'blackberry': False,
#  'lion': False,
#  'sick': False,
#  'exclusive': False,
#  'honored': False,
#  'duplicating': False,
#  'sync': False,
#  'damaged': False,
#  'trash': False,
#  'gone': False,
#  'don': False,
#  'newest': False,
#  'properly': False,
#  'asus': False,
#  'body': False,
#  'ur': False,
#  'half': False,
#  'fault': False,
#  'chris': False,
#  'handle': False,
#  'rest': False,
#  'throw': False,
#  'browsers': False,
#  'brother': False,
#  'another': False,
#  'ical': False,
#  'y': False,
#  'signups': False,
#  'onto': False,
#  'attempts': False,
#  'wonky': False,
#  'come': False,
#  'sells': False,
#  'downloads': False,
#  'data': False,
#  'i0s5': False,
#  'sloppy': False,
#  'fuckingpissed': False,
#  'removable': False,
#  'woods': False,
#  'dropped': False,
#  'ny': False,
#  'replace': False,
#  'useful': False,
#  'check': False,
#  '25mb': False,
#  'clocks': False,
#  'worstupdateever': False,
#  'jobs': False,
#  'overbearing': False,
#  'gigs': False,
#  'told': False,
#  'sooo': False,
#  'times': False,
#  'believe': False,
#  'activating': False,
#  'slows': False,
#  'huge': False,
#  'rip': False,
#  'profitering': False,
#  'imamac': False,
#  'utter': False,
#  'timing': False,
#  'gen': False,
#  'step': False,
#  'gratis': False,
#  'clicking': False,
#  'orging': False,
#  'cu': False,
#  'refurbed': False,
#  'yeah': False,
#  'blue': False,
#  'schedule': False,
#  'youre': False,
#  '3500': False,
#  'macbook': False,
#  'mommy': False,
#  'ring': False,
#  '2001': False,
#  'macosc': False,
#  'apps': False,
#  'n': False,
#  'day305': False,
#  'without': False,
#  'tear': False,
#  'greedy': False,
#  'av': False,
#  'slide': False,
#  'lavoy': False,
#  'dontbemadatmebecause': False,
#  'invested': False,
#  'include': False,
#  'premise': False,
#  'sent': False,
#  '2nd': False,
#  'due': False,
#  'princessofchina': False,
#  's': False,
#  'wish': False,
#  'enabled': False,
#  'hand': False,
#  'know': False,
#  'migrating': False,
#  'bless': False,
#  'autosavesucks': False,
#  'rva': False,
#  'james': False,
#  'resolve': False,
#  'facetime': False,
#  'opening': False,
#  'ios5': False,
#  'whores': False,
#  'making': False,
#  'failing': False,
#  'dilation': False,
#  'wise': False,
#  '4': False,
#  'dst': False,
#  'going': False,
#  '4ss': False,
#  'beautiful': False,
#  'hdv': False,
#  'fucked': False,
#  'disappointing': False,
#  'down': False,
#  'der': False,
#  'previous': False,
#  'anymore': False,
#  'hairline': False,
#  'keys': False,
#  '1hr': False,
#  'chipsets': False,
#  'worst': False,
#  'cant': False,
#  'message': False,
#  '3d': False,
#  '965': False,
#  'send': False,
#  'tech': False,
#  'point': False,
#  'storage': False,
#  'ass': False,
#  'droid': False,
#  'podcast': False,
#  'months': False,
#  'exchange': False,
#  'gatos': False,
#  'relaxing': False,
#  'included': False,
#  'sure': False,
#  'iloveyou': False,
#  'lovemyiphone': False,
#  'newfeature': False,
#  'wait': False,
#  'ipad2': False,
#  'current': False,
#  'restored': False,
#  'guess': False,
#  'today': False,
#  'bahhh': False,
#  'reappeared': False,
#  'bug': False,
#  'durable': False,
#  'lost': False,
#  'required': False,
#  'case': False,
#  'slower': False,
#  'notjustaboutthephone': False,
#  'repair': False,
#  'nuts': False,
#  'guys': False,
#  'lt': False,
#  '5th': False,
#  'lonely': False,
#  'http': False,
#  'sense': False,
#  'kill': False,
#  'time': False,
#  'live': False,
#  'corporate': False,
#  'imessage': False,
#  'two': False,
#  'breaking': False,
#  'showed': False,
#  'sending': False,
#  'parents': False,
#  'wash': False,
#  'word': False,
#  'frustration': False,
#  'bottlenecks': False,
#  'future': False,
#  '27': False,
#  'reason': False,
#  'update': False,
#  'b4': False,
#  'thanks': False,
#  'hide': False,
#  'cracked': False,
#  'such': False,
#  'technology': False,
#  'automatically': False,
#  'awful': False,
#  'improve': False,
#  'sadmac': False,
#  'hockey': False,
#  'appointment': False,
#  'push': False,
#  'products': False,
#  'others': False,
#  'anyway': False,
#  'their': False,
#  'account': False,
#  'o': False,
#  'battery': False,
#  'mouse': False,
#  'connection': False,
#  'suck': False,
#  'usage': False,
#  'millions': False,
#  'surviving': False,
#  'monday': False,
#  'find': False,
#  'metro': False,
#  'la': False,
#  'many': False,
#  'ganna': False,
#  'im': False,
#  'available': False,
#  'productivity': False,
#  'artist': False,
#  'worries': False,
#  'change': False,
#  'loyalty': False,
#  'market': False,
#  'booted': False,
#  'moment': False,
#  'touch': False,
#  'appleupdates2': False,
#  'killed': False,
#  'thunderbolt': False,
#  'million': False,
#  'playing': False,
#  'amongst': False,
#  'camera': False,
#  'hypo': False,
#  'bud': False,
#  'keyboards': False,
#  'wifi': False,
#  'contacts': False,
#  'running': False,
#  'having': False,
#  'lol': False,
#  'outside': False,
#  'in': False,
#  'was': False,
#  'spend': False,
#  'lmfao': False,
#  'him': False,
#  'picking': False,
#  'wasted': False,
#  'authorize': False,
#  'debut': False,
#  'iphone2': False,
#  'ios5atemydingo': False,
#  'month': False,
#  'edge': False,
#  'welcome': False,
#  'ceo': False,
#  'gb': False,
#  'slowly': False,
#  'backchannel': False,
#  'tx': False,
#  'alive': False,
#  'adopterness': False,
#  'etc': False,
#  'up': False,
#  'reservation': False,
#  'team': False,
#  'other': False,
#  'buying': False,
#  'can': False,
#  'gear': False,
#  'king': False,
#  'together': False,
#  'won': False,
#  'trying': False,
#  'miss': False,
#  'beta7': False,
#  'thanksfornothing': False,
#  'amazing': False,
#  'often': False,
#  'hurry': False,
#  'yet': False,
#  'houston': False,
#  'please': False,
#  'means': False,
#  'realise': False,
#  'says': False,
#  'had': False,
#  'humor': False,
#  'how': False,
#  'rot': False,
#  'against': False,
#  'thank': False,
#  'yr': False,
#  'dick': False,
#  'tweet': False,
#  'accounts': False,
#  'by': False,
#  'war': False,
#  'what': False,
#  'begin': False,
#  'questions': False,
#  'key': False,
#  'screw': False,
#  'ban': False,
#  'downloaded': False,
#  'pile': False,
#  'set': False,
#  'obviously': False,
#  'alarm': False,
#  'nexus': False,
#  'c': False,
#  'goodriddance': False,
#  'steps': False,
#  'managed': False,
#  'stop': False,
#  'AT_TOKEN': True,
#  'stolen': False,
#  '365daysofgratefulness': False,
#  'has': False,
#  'iphone': True,
#  'lunch': False,
#  '1st': False,
#  'ringing': False,
#  'book': False,
#  'makemeproud': False,
#  'looking': False,
#  'job': False,
#  'credit': False,
#  'surely': False,
#  'early': False,
#  'doesn': False,
#  'under': False,
#  'those': False,
#  'hut': False,
#  'tragic': False,
#  'somehow': False,
#  'nonstop': False,
#  'iphone4': False,
#  'started': False,
#  'immobile': False,
#  'we': False,
#  'workshop': False,
#  '3gs': False,
#  'power': False,
#  'control': False,
#  'ipod': False,
#  'address': False,
#  'girlfriend': False,
#  'to': True,
#  'could': False,
#  'succeed': False,
#  'lolol': False,
#  'amount': False,
#  'ever': False,
#  'care': False,
#  'ethiopian': False,
#  'earbuds': False,
#  'covent': False,
#  'took': False,
#  'appletv': False,
#  'cord': False,
#  'getting': False,
#  'sweet': False,
#  'immediate': False,
#  'seriously': False,
#  'syncing': False,
#  'wififofum': False,
#  'nz': False,
#  'ipad1': False,
#  'die': False,
#  'mad': False,
#  'year': False,
#  ...}

# %% [markdown]
# ### Step 4: Test Train Split
# Test train split, use [sklearns test train split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) to split the data into 80-20 ratio for training and testing. Here we are not using validation set as our dataset is too small.
# <blockquote>Note: The lists for labels are overwritten beacause each split should return the same labels</blockquote>

# %%
# sentiment_label_Y_task2['class'].value_counts()

# %%
# from sklearn import preprocessing

# %%
# le = preprocessing.LabelEncoder()
# le.fit_transform(sentiment_label_Y_task2['class'].values)
# le.inverse_transform([0, 0, 1, 0])

# %%
# le

# %%
# def changeLabels(df):
#     nlist = []
#     for value in df['class']:
#         #print(value)
#         if value=='Pos':
#             nlist.append(0)
#         elif value=='Neg':
#             nlist.append(1)
#         else:
#             nlist.append(2)
#     return np.array(nlist)

# %%
def test_train_split(featurevectors,labels):
    """
    Returns test train split data

    Args:
        featurevectors : list of feature vectors
    
    Returns: feature_vector_train, feature_vector_test, label_train, label_test
    """
    X = []
    #a = changeLabels(labels)
    Y = labels
    from sklearn import preprocessing
    #le = preprocessing.LabelEncoder()
    #Y = le.fit_transform(labels['class'])
    for i in range(len(featurevectors)):
        X.append(np.array(list(featurevectors[i].values())))
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,shuffle=True)
    return X_train,X_test,y_train,y_test
task1_unigram_features_train, task1_unigram_features_test, task1_label_train_unigram, task1_label_test_unigram=test_train_split(task1_unigram_features,sentiment_label_Y_task1)

task1_bigram_features_train, task1_bigram_features_test, task1_label_train_bigram, task1_label_test_bigram=test_train_split(task1_bigram_features,sentiment_label_Y_task1)

task1_POS_features_train, task1_POS_features_test, task1_label_train_POS, task1_label_test_POS=test_train_split(task1_POS_features,sentiment_label_Y_task1)


task2_unigram_features_train, task2_unigram_features_test, task2_label_train_unigram, task2_label_test_unigram=test_train_split(task2_unigram_features,sentiment_label_Y_task2)

task2_bigram_features_train, task2_bigram_features_test, task2_label_train_bigram, task2_label_test_bigram=test_train_split(task2_bigram_features,sentiment_label_Y_task2)

task2_POS_features_train, task2_POS_features_test, task2_label_train_POS, task2_label_test_POS=test_train_split(task2_POS_features,sentiment_label_Y_task2)

# %%
task1_label_train_unigram
# Out:
#     class
# 87    Pos
# 68    Pos
# 5     Pos
# 391   Neg
# 231   Neg
# ..    ...
# 211   Neg
# 396   Neg
# 283   Neg
# 292   Neg
# 242   Neg
#
# [383 rows x 1 columns]

# %% [markdown]
# ###### Step 5: Modelling and Predictions

# %% [markdown]
# #### Model 1: Niave Bayes
# For the purpose of classification we will use [Niave Bayes](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html) from sklearn. Train the Niave Bayes algorithm on all featurevector variants of task 1 and task 2.<br>
# In order to compare and quantify the goodness of our model we will compute a [classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html). We will also create a [confusion matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) to see what mistakes the model might be making.
#
# First program the train_model and predictions function which are general functions that will be used later on.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
def train_model(model,features,labels):
    """
    Trains a Naive Bayes model 

    Args:
        features : list of feature vectors or X
        labels: targets or Y
        model: Niave Bayes model that is to be trained
    
    Returns: trained model
    """
    model.fit(features,labels)
    return model

# %%
def predictions(model,features):
    """
    Returns predictions from a trained model

    Args:
        features : list of feature vectors or X
        model: Niave Bayes model that is to be trained
    
    Returns: prediction list
    """
    y_predict = model.predict(features)
    
    return y_predict

# %%
task1_label_train_unigram
# Out:
#     class
# 87    Pos
# 68    Pos
# 5     Pos
# 391   Neg
# 231   Neg
# ..    ...
# 211   Neg
# 396   Neg
# 283   Neg
# 292   Neg
# 242   Neg
#
# [383 rows x 1 columns]

# %% [markdown]
# ##### Using the above functions train different models for different feature vectors and  obtain the models predictions for test set.

# %%
#train model on task1_unigram_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task1_unigram_features_train,task1_label_train_unigram.values.ravel())

###___________________________________###

# %%
#Classification report for task1_unigram_features_train
###__________Code_Here________________###
pred=gnb.predict(task1_unigram_features_test)
#print(pred)
#print(type(task1_label_test_unigram))
#print(type(pred))
#print(type(task1_label_test))
###___________________________________###

print(classification_report(task1_label_test_unigram, pred, labels=["Pos", "Neg"]))
cm=confusion_matrix(task1_label_test_unigram,pred)
cm = pd.DataFrame(cm, ['Pos','Neg'], ['Pos','Neg'])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          Pos       0.75      0.70      0.72        30
#          Neg       0.87      0.89      0.88        66
#
#     accuracy                           0.83        96
#    macro avg       0.81      0.80      0.80        96
# weighted avg       0.83      0.83      0.83        96

# %%
##### train model on task1_bigram_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task1_bigram_features_train,task1_label_train_bigram.values.ravel())
###___________________________________###

# %%
#Classification report and confusion matrix for task1_bigram_features_train
###__________Code_Here________________###
pred=predictions(gnb,task1_bigram_features_test)
###___________________________________###

print(classification_report(task1_label_test_bigram, pred, labels=["Pos", "Neg"]))
cm=confusion_matrix(task1_label_test_bigram,pred)
cm = pd.DataFrame(cm, ['Pos','Neg'], ['Pos','Neg'])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
# C:\Users\Dyass\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          Pos       0.00      0.00      0.00        36
#          Neg       0.62      1.00      0.77        60
#
#     accuracy                           0.62        96
#    macro avg       0.31      0.50      0.38        96
# weighted avg       0.39      0.62      0.48        96

# %%
#train model on task1_POS_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task1_POS_features_train,task1_label_train_POS.values.ravel())

###___________________________________###

# %%
#Classification report for task1_POS_features
###__________Code_Here________________###
pred=predictions(gnb,task1_POS_features_test)
###___________________________________###

print(classification_report(task1_label_test_POS, pred, labels=["Pos", "Neg"]))
cm=confusion_matrix(task1_label_test_POS,pred)
cm = pd.DataFrame(cm, ['Pos','Neg'], ['Pos','Neg'])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
# C:\Users\Dyass\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          Pos       0.00      0.00      0.00        33
#          Neg       0.66      1.00      0.79        63
#
#     accuracy                           0.66        96
#    macro avg       0.33      0.50      0.40        96
# weighted avg       0.43      0.66      0.52        96

# %% [markdown]
# #### Compare how performance changes for different feature vectors for task1?

# %% [markdown]
# %%capture
# ###______________Answer_Start_________###
# For task 1, in terms of accuracy,precision,recall,f1-score,micro and macro scores, unigram features outperforms pos and bigram features and pos features outperform bigram features. Fscore and precision are illdefined for bigram and pos features because they result in a 0/0 situation with recall equal to 1 for negative class. The reason might be that model gets too much complex in these cases and we have not done any kind of stop words pre-processing
# ###______________Answer_End_________###

# %% [markdown]
# ##### Repeat the above steps for task2

# %%
#train model on task2_unigram_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task2_unigram_features_train,task2_label_train_unigram.values.ravel())

###___________________________________###

# %%
#Classification report for task2_unigram_features
###__________Code_Here________________###
pred=predictions(gnb,task2_unigram_features_test)
###___________________________________###

print(classification_report(task2_label_test_unigram, pred, labels=["Pos", "Neg","Neutral"]))
cm=confusion_matrix(task2_label_test_unigram,pred)
cm = pd.DataFrame(cm, ["Pos","Neg","Neutral"], ["Pos","Neg","Neutral"])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          Pos       0.75      0.24      0.36        25
#          Neg       0.62      0.71      0.66        66
#      Neutral       0.75      0.80      0.78       107
#
#     accuracy                           0.70       198
#    macro avg       0.71      0.59      0.60       198
# weighted avg       0.71      0.70      0.69       198

# %%
#train model on task2_bigram_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task2_bigram_features_train,task2_label_train_bigram.values.ravel())

###___________________________________###

# %%
#Classification report for task2_bigram_features
###__________Code_Here________________###
pred=predictions(gnb,task2_bigram_features_test)
###___________________________________###

print(classification_report(task2_label_test_bigram, pred, labels=["Pos", "Neg","Neutral"]))
cm=confusion_matrix(task2_label_test_bigram,pred)
cm = pd.DataFrame(cm, ["Pos","Neg","Neutral"], ["Pos","Neg","Neutral"])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
# C:\Users\Dyass\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          Pos       0.00      0.00      0.00        40
#          Neg       0.00      0.00      0.00        59
#      Neutral       0.50      1.00      0.67        99
#
#     accuracy                           0.50       198
#    macro avg       0.17      0.33      0.22       198
# weighted avg       0.25      0.50      0.33       198

# %%
#train model on task2_POS_features_train
###__________Code_Here________________###
gnb = MultinomialNB()
gnb = train_model(gnb,task2_POS_features_train,task2_label_train_POS.values.ravel())
###___________________________________###

# %%
#Classification report for task2_POS_features
###__________Code_Here________________###
pred=predictions(gnb,task2_POS_features_test)
###___________________________________###

print(classification_report(task2_label_test_POS, pred, labels=["Pos", "Neg","Neutral"]))
cm=confusion_matrix(task2_label_test_POS,pred)
cm = pd.DataFrame(cm, ["Pos","Neg","Neutral"], ["Pos","Neg","Neutral"])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
# C:\Users\Dyass\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          Pos       0.00      0.00      0.00        29
#          Neg       0.00      0.00      0.00        70
#      Neutral       0.50      1.00      0.67        99
#
#     accuracy                           0.50       198
#    macro avg       0.17      0.33      0.22       198
# weighted avg       0.25      0.50      0.33       198

# %% [markdown]
# #####  How does the addition of an extra class affect the learning of our algorithm? Which pairs of classes are most often confused? Why might that be?

# %% [markdown]
# %%capture
# ###______________Answer_Start_________###
# The addition of extra class makes our model predict majority of the testing examples as negative. Neutral and positive classes are mostly confused with  negative classes. The reason might be that the number of training examples are skewed meaning that the classes used for training are mostly negative classes due to which model is classifying all of the training data as negative
#
# ###______________Answer_End_________###

# %% [markdown]
# ### We can further create more complex features by combining different ngram features to  improve performance. We can also remove words that occur rarely in our dataset to reduce the size of our feature vectors.

# %% [markdown]
# #### Model2: Logistic Regression
# We will now use [logistic regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) to explore the improvements stated above. To create complex feature vectors we will use [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) from sklearn.<br>
# We will play around with two parameters of CountVectorizer:
# <ul>
#     <li>min_df ( = 5): defines the minimum frequency of a word for it to be counted as a feature, in this case the word should have a frequency count of atleast 5.</li>
#     <li>ngram_range (= (2,2)): The ngram_range parameter is a tuple. It defines the minimum and maximum length of sequence of tokens considered. In this case, this length is 2. So, this will find sequence of 2 tokens like — ‘but the’, ‘wise man’ etc.</li>
# </ul>
# Use the ngram_range=(1,2) and min_df=5.
#
# Hint: See the fit and transform functions<br>
# <i>If you get stuck, you can look at our solution</i> [here](https://ibb.co/p4BFdvs)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
x,y = tweet_X_task1,sentiment_label_Y_task1

# %%
x['text']=x['text'].apply(', '.join)

# %%
#xTrain,xTest,yTrain,yTest = train_test_split(tweet_X_task1,sentiment_label_Y_task1)

# %%
#Need to jo rejoining

# %%
#create complex features
###__________Code_Here________________###

vectorizer = CountVectorizer(min_df=5,ngram_range=(2,2))

x = vectorizer.fit_transform(x['text'])
xTrain,xTest,yTrain,yTest = train_test_split(x,sentiment_label_Y_task1)
###___________________________________###

# %%
#train logistic regression model
###__________Code_Here________________###
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression()
logistic.fit(xTrain,yTrain.values.ravel())

###___________________________________###
# Out:
# C:\Users\Dyass\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#train model on complex_feature
###__________Code_Here________________###
pred= logistic.predict(xTest)
#print(pred)
###___________________________________###
#print(len(pred),len(yTest))
print(classification_report(yTest, pred, labels=["Pos", "Neg",]))
cm=confusion_matrix(yTest,pred)
cm = pd.DataFrame(cm, ["Pos","Neg"], ["Pos","Neg"])# matrix,names row,names col,
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.5) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 11}, fmt="d") # font size
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          Pos       0.60      0.20      0.31        44
#          Neg       0.67      0.92      0.77        76
#
#     accuracy                           0.66       120
#    macro avg       0.63      0.56      0.54       120
# weighted avg       0.64      0.66      0.60       120

# %% [markdown]
# #### You can play around with ngram_range and min_df to further improve performance.

# %% [markdown]
# Great you have completed the first task now move onto [Part 2](https://ibb.co/MfpxHZh).
